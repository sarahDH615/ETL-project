# %%
# import dependencies
import pandas as pd
import datetime as dt

# %%
# attempt to increase col display
pd.set_option('display.max_columns', 28)

# %%
# read in csv
policy_df = pd.read_csv('Raw/policy_list.csv')
policy_df.sample(7)
# Out:
#          ID     COUNTRY_NAME ISO3 ISO2 POLICY_TYPE   POLICY_SUBTYPE  \
# 138    1976         Paraguay  PRY   PY    COMPLETE    CITIZEN_EXCEP
# 578    1307         Botswana  BWA   BW     PARTIAL  CITIZENSHIP_BAN
# 1027  12141         Bulgaria  BGR   BG     PARTIAL   BORDER_CLOSURE
# 822     966  Solomon Islands  SLB   SB     PARTIAL   BORDER_CLOSURE
# 418    EB57     Cook Islands  COK   CK    COMPLETE       WORK_EXCEP
# 160    7120           Rwanda  RWA   RW    COMPLETE    CITIZEN_EXCEP
# 622    SN33         Slovenia  SVN   SI     PARTIAL  CITIZENSHIP_BAN
#
#      START_DATE  END_DATE  AIR AIR_TYPE TARGETS_AIR  LAND LAND_TYPE  \
# 138    03_16_20  03_30_20    0      NaN         NaN     0       NaN
# 578    03_19_20      NONE    0      NaN         NaN     0       NaN
# 1027   04_24_20  04_26_20    0      NaN         NaN     1  Specific
# 822    05_21_20  06_21_20    0      NaN         NaN     0       NaN
# 418    03_24_20  05_12_20    0      NaN         NaN     0       NaN
# 160    03_21_20  04_04_20    0      NaN         NaN     0       NaN
# 622    03_31_20  05_12_20    0      NaN         NaN     0       NaN
#
#                                            TARGETS_LAND  ...  VISA_BAN  \
# 138                                                 NaN  ...         0
# 578                                                 NaN  ...         0
# 1027  land border with Turkey is closed to persons a...  ...         0
# 822                                                 NaN  ...         0
# 418                                                 NaN  ...         0
# 160                                                 NaN  ...         0
# 622                                                 NaN  ...         0
#
#      VISA_BAN_TYPE VISA_BAN_LIST  CITIZEN_EXCEP  \
# 138            NaN           NaN              1
# 578            NaN           NaN              0
# 1027           NaN           NaN              0
# 822            NaN           NaN              0
# 418            NaN           NaN              1
# 160            NaN           NaN              1
# 622            NaN           NaN              0
#
#                                      CITIZEN_EXCEP_LIST  COUNTRY_EXCEP  \
# 138                    Residents, Citizens, Diplomats,               0
# 578                                                 NaN              0
# 1027                                                NaN              0
# 822                                                 NaN              0
# 418   nationals, residents, family of nationals and ...              1
# 160                        Citizens and legal residents              0
# 622                                                 NaN              0
#
#      COUNTRY_EXCEP_LIST  WORK_EXCEP  \
# 138                 NaN           0
# 578                 NaN           0
# 1027                NaN           0
# 822                 NaN           0
# 418        New Zealand            1
# 160                 NaN           0
# 622                 NaN           0
#
#                                                 SOURCE0  \
# 138   https://web.archive.org/web/20200321163104/htt...
# 578   https://web.archive.org/web/20200321095613/htt...
# 1027  https://bnt.bg/bg/a/coronavirus-temporary-ban-...
# 822   https://web.archive.org/web/20200621231041/htt...
# 418   https://web.archive.org/web/20200501174105/htt...
# 160   http://web.archive.org/web/20200430171912/http...
# 622   https://web.archive.org/web/20200605205501/htt...
#
#                                                 SOURCE1  \
# 138   https://web.archive.org/web/20200320135415/htt...
# 578                                                 NaN
# 1027                                                NaN
# 822                                                 NaN
# 418                                                 NaN
# 160                                                 NaN
# 622                                                 NaN
#
#                                                 SOURCE2  \
# 138   https://web.archive.org/web/20200320222639/htt...
# 578                                                 NaN
# 1027                                                NaN
# 822                                                 NaN
# 418                                                 NaN
# 160                                                 NaN
# 622                                                 NaN
#
#                                                 SOURCE3  SOURCE4 SOURCE5
# 138   http://www.migraciones.gov.py/index.php/notici...      NaN     NaN
# 578                                                 NaN      NaN     NaN
# 1027                                                NaN      NaN     NaN
# 822                                                 NaN      NaN     NaN
# 418                                                 NaN      NaN     NaN
# 160                                                 NaN      NaN     NaN
# 622                                                 NaN      NaN     NaN
#
# [7 rows x 37 columns]

# %%
# viewing current columns
policy_df.columns
# Out:
# Index(['ID', 'COUNTRY_NAME', 'ISO3', 'ISO2', 'POLICY_TYPE', 'POLICY_SUBTYPE',
#        'START_DATE', 'END_DATE', 'AIR', 'AIR_TYPE', 'TARGETS_AIR', 'LAND',
#        'LAND_TYPE', 'TARGETS_LAND', 'SEA', 'SEA_TYPE', 'TARGETS_SEA',
#        'CITIZEN', 'CITIZEN_LIST', 'HISTORY_BAN', 'HISTORY_BAN_LIST', 'REFUGEE',
#        'REFUGEE_LIST', 'VISA_BAN', 'VISA_BAN_TYPE', 'VISA_BAN_LIST',
#        'CITIZEN_EXCEP', 'CITIZEN_EXCEP_LIST', 'COUNTRY_EXCEP',
#        'COUNTRY_EXCEP_LIST', 'WORK_EXCEP', 'SOURCE0', 'SOURCE1', 'SOURCE2',
#        'SOURCE3', 'SOURCE4', 'SOURCE5'],
#       dtype='object')

# %%
# taking columns subset
policy_df = policy_df[['COUNTRY_NAME', 'ISO3', 'POLICY_TYPE', 'POLICY_SUBTYPE',
       'START_DATE', 'AIR', 'AIR_TYPE', 'TARGETS_AIR', 'LAND',
       'LAND_TYPE', 'TARGETS_LAND', 'SEA', 'SEA_TYPE', 'TARGETS_SEA',
       'CITIZEN', 'CITIZEN_LIST', 'HISTORY_BAN', 'HISTORY_BAN_LIST', 'REFUGEE',
       'REFUGEE_LIST', 'VISA_BAN', 'VISA_BAN_TYPE', 'VISA_BAN_LIST',
       'CITIZEN_EXCEP', 'CITIZEN_EXCEP_LIST', 'COUNTRY_EXCEP',
       'COUNTRY_EXCEP_LIST', 'WORK_EXCEP']]
policy_df.columns
# Out:
# Index(['COUNTRY_NAME', 'ISO3', 'POLICY_TYPE', 'POLICY_SUBTYPE', 'START_DATE',
#        'AIR', 'AIR_TYPE', 'TARGETS_AIR', 'LAND', 'LAND_TYPE', 'TARGETS_LAND',
#        'SEA', 'SEA_TYPE', 'TARGETS_SEA', 'CITIZEN', 'CITIZEN_LIST',
#        'HISTORY_BAN', 'HISTORY_BAN_LIST', 'REFUGEE', 'REFUGEE_LIST',
#        'VISA_BAN', 'VISA_BAN_TYPE', 'VISA_BAN_LIST', 'CITIZEN_EXCEP',
#        'CITIZEN_EXCEP_LIST', 'COUNTRY_EXCEP', 'COUNTRY_EXCEP_LIST',
#        'WORK_EXCEP'],
#       dtype='object')

# %%
# renaming the columns
policy_df.columns = ['Country', 'Country_id', 'Policy_type', 'Policy_subtype', 'Policy_start_date', 'Air_ban',
                             'Air_ban_type', 'Air_ban_info', 'Land_ban', 'Land_ban_type', 'Land_ban_info', 
                             'Sea_ban', 'Sea_ban_type', 'Sea_ban_info','Citizen_ban', 'Citizen_ban_info', 
                             'Travel_history_ban', 'Travel_history_ban_info', 
                             'Refugee_ban', 'Refugee_ban_info', 
                             'Visa_ban', 'Visa_ban_list', 'Visa_ban_info', 
                             'Citizen_exceptions', 'Citizen_exceptions_info', 
                             'Country_exceptions', 'Country_exceptions_info', 'Work_exceptions']
policy_df.columns
# Out:
# Index(['Country', 'Country_id', 'Policy_type', 'Policy_subtype',
#        'Policy_start_date', 'Air_ban', 'Air_ban_type', 'Air_ban_info',
#        'Land_ban', 'Land_ban_type', 'Land_ban_info', 'Sea_ban', 'Sea_ban_type',
#        'Sea_ban_info', 'Citizen_ban', 'Citizen_ban_info', 'Travel_history_ban',
#        'Travel_history_ban_info', 'Refugee_ban', 'Refugee_ban_info',
#        'Visa_ban', 'Visa_ban_list', 'Visa_ban_info', 'Citizen_exceptions',
#        'Citizen_exceptions_info', 'Country_exceptions',
#        'Country_exceptions_info', 'Work_exceptions'],
#       dtype='object')

# %%
# re-viewing the columns
policy_df.head()
# Out:
#                                   Country Country_id Policy_type  \
# 0                       Brunei Darussalam        BRN    COMPLETE
# 1                                 Morocco        MAR    COMPLETE
# 2  Korea, Democratic People's Republic of        PRK    COMPLETE
# 3                        Marshall Islands        MHL    COMPLETE
# 4        Lao People's Democratic Republic        LAO    COMPLETE
#
#    Policy_subtype Policy_start_date  Air_ban Air_ban_type Air_ban_info  \
# 0  ESSENTIAL_ONLY          03_23_20        0          NaN          NaN
# 1  ESSENTIAL_ONLY          03_20_20        0          NaN          NaN
# 2  ESSENTIAL_ONLY          01_22_20        0          NaN          NaN
# 3  ESSENTIAL_ONLY          03_08_20        0          NaN          NaN
# 4  ESSENTIAL_ONLY          03_16_20        0          NaN          NaN
#
#    Land_ban Land_ban_type Land_ban_info  Sea_ban Sea_ban_type Sea_ban_info  \
# 0         0           NaN           NaN        0          NaN          NaN
# 1         0           NaN           NaN        0          NaN          NaN
# 2         0           NaN           NaN        0          NaN          NaN
# 3         0           NaN           NaN        0          NaN          NaN
# 4         0           NaN           NaN        0          NaN          NaN
#
#    Citizen_ban Citizen_ban_info  Travel_history_ban Travel_history_ban_info  \
# 0            0              NaN                   0                     NaN
# 1            0              NaN                   0                     NaN
# 2            0              NaN                   0                     NaN
# 3            0              NaN                   0                     NaN
# 4            0              NaN                   0                     NaN
#
#    Refugee_ban Refugee_ban_info  Visa_ban Visa_ban_list Visa_ban_info  \
# 0            0              NaN         0           NaN           NaN
# 1            0              NaN         0           NaN           NaN
# 2            0              NaN         0           NaN           NaN
# 3            0              NaN         0           NaN           NaN
# 4            0              NaN         0           NaN           NaN
#
#    Citizen_exceptions Citizen_exceptions_info  Country_exceptions  \
# 0                   0                     NaN                   0
# 1                   0                     NaN                   0
# 2                   0                     NaN                   0
# 3                   0                     NaN                   0
# 4                   0                     NaN                   0
#
#   Country_exceptions_info  Work_exceptions
# 0                     NaN                0
# 1                     NaN                0
# 2                     NaN                0
# 3                     NaN                0
# 4                     NaN                0

# %%
# checking which cols have null values
policy_df.isnull().sum()
# Out:
# Country                       0
# Country_id                    0
# Policy_type                   0
# Policy_subtype                0
# Policy_start_date             0
# Air_ban                       0
# Air_ban_type                891
# Air_ban_info               1034
# Land_ban                      0
# Land_ban_type              1084
# Land_ban_info              1156
# Sea_ban                       0
# Sea_ban_type               1211
# Sea_ban_info               1242
# Citizen_ban                   0
# Citizen_ban_info           1209
# Travel_history_ban            0
# Travel_history_ban_info    1154
# Refugee_ban                   0
# Refugee_ban_info           1270
# Visa_ban                      0
# Visa_ban_list              1181
# Visa_ban_info              1236
# Citizen_exceptions            0
# Citizen_exceptions_info     904
# Country_exceptions            0
# Country_exceptions_info    1101
# Work_exceptions               0
# dtype: int64

# %%
# renaming NaNs
policy_df.fillna('no policy', inplace=True)
policy_df.head()
# Out:
#                                   Country Country_id Policy_type  \
# 0                       Brunei Darussalam        BRN    COMPLETE
# 1                                 Morocco        MAR    COMPLETE
# 2  Korea, Democratic People's Republic of        PRK    COMPLETE
# 3                        Marshall Islands        MHL    COMPLETE
# 4        Lao People's Democratic Republic        LAO    COMPLETE
#
#    Policy_subtype Policy_start_date  Air_ban Air_ban_type Air_ban_info  \
# 0  ESSENTIAL_ONLY          03_23_20        0    no policy    no policy
# 1  ESSENTIAL_ONLY          03_20_20        0    no policy    no policy
# 2  ESSENTIAL_ONLY          01_22_20        0    no policy    no policy
# 3  ESSENTIAL_ONLY          03_08_20        0    no policy    no policy
# 4  ESSENTIAL_ONLY          03_16_20        0    no policy    no policy
#
#    Land_ban Land_ban_type Land_ban_info  Sea_ban Sea_ban_type Sea_ban_info  \
# 0         0     no policy     no policy        0    no policy    no policy
# 1         0     no policy     no policy        0    no policy    no policy
# 2         0     no policy     no policy        0    no policy    no policy
# 3         0     no policy     no policy        0    no policy    no policy
# 4         0     no policy     no policy        0    no policy    no policy
#
#    Citizen_ban Citizen_ban_info  Travel_history_ban Travel_history_ban_info  \
# 0            0        no policy                   0               no policy
# 1            0        no policy                   0               no policy
# 2            0        no policy                   0               no policy
# 3            0        no policy                   0               no policy
# 4            0        no policy                   0               no policy
#
#    Refugee_ban Refugee_ban_info  Visa_ban Visa_ban_list Visa_ban_info  \
# 0            0        no policy         0     no policy     no policy
# 1            0        no policy         0     no policy     no policy
# 2            0        no policy         0     no policy     no policy
# 3            0        no policy         0     no policy     no policy
# 4            0        no policy         0     no policy     no policy
#
#    Citizen_exceptions Citizen_exceptions_info  Country_exceptions  \
# 0                   0               no policy                   0
# 1                   0               no policy                   0
# 2                   0               no policy                   0
# 3                   0               no policy                   0
# 4                   0               no policy                   0
#
#   Country_exceptions_info  Work_exceptions
# 0               no policy                0
# 1               no policy                0
# 2               no policy                0
# 3               no policy                0
# 4               no policy                0

# %%
# finding length of dataframe
len(policy_df)
# Out:
# 1271

# %%
# finding number of countries in df
len(policy_df['Country_id'].unique())
# Out:
# 243

# %%
# sorting the country id alphabetically
sorted_policy_df = policy_df.sort_values('Country_id')
sorted_policy_df.head(20)
# Out:
#           Country Country_id Policy_type    Policy_subtype Policy_start_date  \
# 194         Aruba        ABW    COMPLETE     CITIZEN_EXCEP          03_16_20
# 296         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY          07_10_20
# 84          Aruba        ABW    COMPLETE    ESSENTIAL_ONLY          03_26_20
# 295         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY          07_01_20
# 81          Aruba        ABW    COMPLETE    ESSENTIAL_ONLY          03_26_20
# 294         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY          06_15_20
# 210         Aruba        ABW    COMPLETE     CITIZEN_EXCEP          04_21_20
# 209         Aruba        ABW    COMPLETE     CITIZEN_EXCEP          03_17_20
# 217         Aruba        ABW    COMPLETE     CITIZEN_EXCEP          03_16_20
# 738   Afghanistan        AFG     PARTIAL    BORDER_CLOSURE          02_24_20
# 1017  Afghanistan        AFG     PARTIAL    BORDER_CLOSURE          03_24_20
# 1252       Angola        AGO     PARTIAL    BORDER_CLOSURE          10_19_20
# 1251       Angola        AGO     PARTIAL    BORDER_CLOSURE          10_01_20
# 732        Angola        AGO     PARTIAL       HISTORY_BAN          03_03_20
# 16         Angola        AGO    COMPLETE    ESSENTIAL_ONLY          03_20_20
# 251        Angola        AGO    COMPLETE     CITIZEN_EXCEP          05_26_20
# 733        Angola        AGO     PARTIAL       HISTORY_BAN          03_18_20
# 64       Anguilla        AIA    COMPLETE    ESSENTIAL_ONLY          03_20_20
# 299      Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY          07_12_20
# 1115     Anguilla        AIA     PARTIAL    BORDER_CLOSURE          03_24_20
#
#       Air_ban Air_ban_type                                       Air_ban_info  \
# 194         0    no policy                                          no policy
# 296         0    no policy                                          no policy
# 84          0    no policy                                          no policy
# 295         0    no policy                                          no policy
# 81          0    no policy                                          no policy
# 294         0    no policy                                          no policy
# 210         0    no policy                                          no policy
# 209         0    no policy                                          no policy
# 217         0    no policy                                          no policy
# 738         0    no policy                                          no policy
# 1017        1     Specific  all commercial flights suspended except for so...
# 1252        1     Specific  Afghanistan, Aland Islands, Albania, Algeria, ...
# 1251        1     Specific  Afghanistan, Aland Islands, Albania, Algeria, ...
# 732         0    no policy                                          no policy
# 16          0    no policy                                          no policy
# 251         0    no policy                                          no policy
# 733         0    no policy                                          no policy
# 64          0    no policy                                          no policy
# 299         0    no policy                                          no policy
# 1115        1          All                                          no policy
#
#       Land_ban Land_ban_type Land_ban_info  Sea_ban Sea_ban_type  \
# 194          0     no policy     no policy        0    no policy
# 296          0     no policy     no policy        0    no policy
# 84           0     no policy     no policy        0    no policy
# 295          0     no policy     no policy        0    no policy
# 81           0     no policy     no policy        0    no policy
# 294          0     no policy     no policy        0    no policy
# 210          0     no policy     no policy        0    no policy
# 209          0     no policy     no policy        0    no policy
# 217          0     no policy     no policy        0    no policy
# 738          1      Specific          Iran        0    no policy
# 1017         0     no policy     no policy        0    no policy
# 1252         1           All     no policy        1          All
# 1251         1           All     no policy        1          All
# 732          0     no policy     no policy        0    no policy
# 16           0     no policy     no policy        0    no policy
# 251          0     no policy     no policy        0    no policy
# 733          0     no policy     no policy        0    no policy
# 64           0     no policy     no policy        0    no policy
# 299          0     no policy     no policy        0    no policy
# 1115         0     no policy     no policy        1     Specific
#
#                                            Sea_ban_info  Citizen_ban  \
# 194                                           no policy            0
# 296                                           no policy            0
# 84                                            no policy            0
# 295                                           no policy            0
# 81                                            no policy            0
# 294                                           no policy            0
# 210                                           no policy            0
# 209                                           no policy            0
# 217                                           no policy            0
# 738                                           no policy            0
# 1017                                          no policy            0
# 1252                                          no policy            0
# 1251                                          no policy            0
# 732                                           no policy            0
# 16                                            no policy            0
# 251                                           no policy            0
# 733                                           no policy            0
# 64                                            no policy            0
# 299                                           no policy            0
# 1115  Blowing Point Ferry Terminal closed until furt...            0
#
#      Citizen_ban_info  Travel_history_ban  \
# 194         no policy                   0
# 296         no policy                   0
# 84          no policy                   0
# 295         no policy                   0
# 81          no policy                   0
# 294         no policy                   0
# 210         no policy                   0
# 209         no policy                   0
# 217         no policy                   0
# 738         no policy                   0
# 1017        no policy                   0
# 1252        no policy                   0
# 1251        no policy                   0
# 732         no policy                   1
# 16          no policy                   0
# 251         no policy                   0
# 733         no policy                   1
# 64          no policy                   0
# 299         no policy                   0
# 1115        no policy                   0
#
#                                 Travel_history_ban_info  Refugee_ban  \
# 194                                           no policy            0
# 296                                           no policy            0
# 84                                            no policy            0
# 295                                           no policy            0
# 81                                            no policy            0
# 294                                           no policy            0
# 210                                           no policy            0
# 209                                           no policy            0
# 217                                           no policy            0
# 738                                           no policy            0
# 1017                                          no policy            0
# 1252                                          no policy            0
# 1251                                          no policy            0
# 732                     China, South Korea, Italy, Iran            0
# 16                                            no policy            0
# 251                                           no policy            0
# 733   China, South Korea, Italy, Iran, Portugal, Spa...            0
# 64                                            no policy            0
# 299                                           no policy            0
# 1115                                          no policy            0
#
#      Refugee_ban_info  Visa_ban Visa_ban_list Visa_ban_info  \
# 194         no policy         0     no policy     no policy
# 296         no policy         0     no policy     no policy
# 84          no policy         0     no policy     no policy
# 295         no policy         0     no policy     no policy
# 81          no policy         0     no policy     no policy
# 294         no policy         0     no policy     no policy
# 210         no policy         0     no policy     no policy
# 209         no policy         0     no policy     no policy
# 217         no policy         0     no policy     no policy
# 738         no policy         0     no policy     no policy
# 1017        no policy         0     no policy     no policy
# 1252        no policy         0     no policy     no policy
# 1251        no policy         0     no policy     no policy
# 732         no policy         0     no policy     no policy
# 16          no policy         0     no policy     no policy
# 251         no policy         0     no policy     no policy
# 733         no policy         0     no policy     no policy
# 64          no policy         0     no policy     no policy
# 299         no policy         0     no policy     no policy
# 1115        no policy         0     no policy     no policy
#
#       Citizen_exceptions                            Citizen_exceptions_info  \
# 194                    1                      citizens, permanent residents
# 296                    1  residents with prior authorization, non-reside...
# 84                     0                                          no policy
# 295                    1  residents with prior authorization, non-reside...
# 81                     0                                          no policy
# 294                    1  residents with prior authorization, non-reside...
# 210                    1  residents of Aruba with prior authorization, n...
# 209                    1                                          residents
# 217                    1  citizens, permanent residents, family members ...
# 738                    0                                          no policy
# 1017                   0                                          no policy
# 1252                   0                                          no policy
# 1251                   0                                          no policy
# 732                    0                                          no policy
# 16                     0                                          no policy
# 251                    1                       nationals, foreign residents
# 733                    0                                          no policy
# 64                     0                                          no policy
# 299                    1                                citizens, residents
# 1115                   0                                          no policy
#
#       Country_exceptions                            Country_exceptions_info  \
# 194                    0                                          no policy
# 296                    1  Antiga and Barbuda, The Bahamas, Barbados, Cub...
# 84                     0                                          no policy
# 295                    1  Antiga and Barbuda, The Bahamas, Barbados, Cub...
# 81                     0                                          no policy
# 294                    1           Curacao, Bonaire, St. Eustatius and Saba
# 210                    0                                          no policy
# 209                    0                                          no policy
# 217                    0                                          no policy
# 738                    0                                          no policy
# 1017                   0                                          no policy
# 1252                   0                                          no policy
# 1251                   0                                          no policy
# 732                    0                                          no policy
# 16                     0                                          no policy
# 251                    0                                          no policy
# 733                    0                                          no policy
# 64                     0                                          no policy
# 299                    1  Aruba, Bonaire, St Eustatius and Saba, Belize,...
# 1115                   0                                          no policy
#
#       Work_exceptions
# 194                 0
# 296                 0
# 84                  0
# 295                 0
# 81                  0
# 294                 0
# 210                 0
# 209                 0
# 217                 0
# 738                 0
# 1017                0
# 1252                0
# 1251                0
# 732                 0
# 16                  0
# 251                 0
# 733                 0
# 64                  0
# 299                 0
# 1115                0

# %%
# finding dtype for Start Date col
sorted_policy_df['Policy_start_date'].dtype
# Out:
# dtype('O')

# %%
# impossible date
sorted_policy_df[sorted_policy_df['Policy_start_date'] == '04_31_20']
# Out:
#     Country Country_id Policy_type  Policy_subtype Policy_start_date  Air_ban  \
# 93  Ecuador        ECU    COMPLETE  ESSENTIAL_ONLY          04_31_20        0
#
#    Air_ban_type Air_ban_info  Land_ban Land_ban_type Land_ban_info  Sea_ban  \
# 93    no policy    no policy         0     no policy     no policy        0
#
#    Sea_ban_type Sea_ban_info  Citizen_ban Citizen_ban_info  \
# 93    no policy    no policy            0        no policy
#
#     Travel_history_ban Travel_history_ban_info  Refugee_ban Refugee_ban_info  \
# 93                   0               no policy            0        no policy
#
#     Visa_ban Visa_ban_list Visa_ban_info  Citizen_exceptions  \
# 93         0     no policy     no policy                   0
#
#    Citizen_exceptions_info  Country_exceptions Country_exceptions_info  \
# 93               no policy                   0               no policy
#
#     Work_exceptions
# 93                0

# %%
# formatting dates for use in datetime
# replacing nons and 0s with fake date 
dates_list = [x.replace('_', '-') for x in sorted_policy_df['Policy_start_date']]
dates_list_start = ['01-01-01' if x == 'NONE' or x == '0' else x for x in dates_list]
# educated guess as to end date of errant date shown in above cell
dates_list_edited = ['04-21-20' if x == '04-31-20' else x for x in dates_list_start]

# %%
# replacing Start Date col w/ edited dates list
sorted_policy_df['Policy_start_date'] = dates_list_edited
sorted_policy_df.head()
# Out:
#     Country Country_id Policy_type    Policy_subtype Policy_start_date  \
# 194   Aruba        ABW    COMPLETE     CITIZEN_EXCEP          03-16-20
# 296   Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY          07-10-20
# 84    Aruba        ABW    COMPLETE    ESSENTIAL_ONLY          03-26-20
# 295   Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY          07-01-20
# 81    Aruba        ABW    COMPLETE    ESSENTIAL_ONLY          03-26-20
#
#      Air_ban Air_ban_type Air_ban_info  Land_ban Land_ban_type Land_ban_info  \
# 194        0    no policy    no policy         0     no policy     no policy
# 296        0    no policy    no policy         0     no policy     no policy
# 84         0    no policy    no policy         0     no policy     no policy
# 295        0    no policy    no policy         0     no policy     no policy
# 81         0    no policy    no policy         0     no policy     no policy
#
#      Sea_ban Sea_ban_type Sea_ban_info  Citizen_ban Citizen_ban_info  \
# 194        0    no policy    no policy            0        no policy
# 296        0    no policy    no policy            0        no policy
# 84         0    no policy    no policy            0        no policy
# 295        0    no policy    no policy            0        no policy
# 81         0    no policy    no policy            0        no policy
#
#      Travel_history_ban Travel_history_ban_info  Refugee_ban Refugee_ban_info  \
# 194                   0               no policy            0        no policy
# 296                   0               no policy            0        no policy
# 84                    0               no policy            0        no policy
# 295                   0               no policy            0        no policy
# 81                    0               no policy            0        no policy
#
#      Visa_ban Visa_ban_list Visa_ban_info  Citizen_exceptions  \
# 194         0     no policy     no policy                   1
# 296         0     no policy     no policy                   1
# 84          0     no policy     no policy                   0
# 295         0     no policy     no policy                   1
# 81          0     no policy     no policy                   0
#
#                                Citizen_exceptions_info  Country_exceptions  \
# 194                      citizens, permanent residents                   0
# 296  residents with prior authorization, non-reside...                   1
# 84                                           no policy                   0
# 295  residents with prior authorization, non-reside...                   1
# 81                                           no policy                   0
#
#                                Country_exceptions_info  Work_exceptions
# 194                                          no policy                0
# 296  Antiga and Barbuda, The Bahamas, Barbados, Cub...                0
# 84                                           no policy                0
# 295  Antiga and Barbuda, The Bahamas, Barbados, Cub...                0
# 81                                           no policy                0

# %%
# converting Start Date col to dtype datetime
sorted_policy_df['Policy_start_date'] = pd.to_datetime(sorted_policy_df['Policy_start_date'])

# %%
# checking dtype
sorted_policy_df['Policy_start_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# sorting by country id then start date
double_sorted_policy_df = sorted_policy_df.sort_values(['Country_id','Policy_start_date'])
double_sorted_policy_df.head()
# Out:
#     Country Country_id Policy_type  Policy_subtype Policy_start_date  Air_ban  \
# 194   Aruba        ABW    COMPLETE   CITIZEN_EXCEP        2020-03-16        0
# 217   Aruba        ABW    COMPLETE   CITIZEN_EXCEP        2020-03-16        0
# 209   Aruba        ABW    COMPLETE   CITIZEN_EXCEP        2020-03-17        0
# 84    Aruba        ABW    COMPLETE  ESSENTIAL_ONLY        2020-03-26        0
# 81    Aruba        ABW    COMPLETE  ESSENTIAL_ONLY        2020-03-26        0
#
#     Air_ban_type Air_ban_info  Land_ban Land_ban_type Land_ban_info  Sea_ban  \
# 194    no policy    no policy         0     no policy     no policy        0
# 217    no policy    no policy         0     no policy     no policy        0
# 209    no policy    no policy         0     no policy     no policy        0
# 84     no policy    no policy         0     no policy     no policy        0
# 81     no policy    no policy         0     no policy     no policy        0
#
#     Sea_ban_type Sea_ban_info  Citizen_ban Citizen_ban_info  \
# 194    no policy    no policy            0        no policy
# 217    no policy    no policy            0        no policy
# 209    no policy    no policy            0        no policy
# 84     no policy    no policy            0        no policy
# 81     no policy    no policy            0        no policy
#
#      Travel_history_ban Travel_history_ban_info  Refugee_ban Refugee_ban_info  \
# 194                   0               no policy            0        no policy
# 217                   0               no policy            0        no policy
# 209                   0               no policy            0        no policy
# 84                    0               no policy            0        no policy
# 81                    0               no policy            0        no policy
#
#      Visa_ban Visa_ban_list Visa_ban_info  Citizen_exceptions  \
# 194         0     no policy     no policy                   1
# 217         0     no policy     no policy                   1
# 209         0     no policy     no policy                   1
# 84          0     no policy     no policy                   0
# 81          0     no policy     no policy                   0
#
#                                Citizen_exceptions_info  Country_exceptions  \
# 194                      citizens, permanent residents                   0
# 217  citizens, permanent residents, family members ...                   0
# 209                                          residents                   0
# 84                                           no policy                   0
# 81                                           no policy                   0
#
#     Country_exceptions_info  Work_exceptions
# 194               no policy                0
# 217               no policy                0
# 209               no policy                0
# 84                no policy                0
# 81                no policy                0

# %%
# keeping only the rows with the most recent date for each country
last_date_df = double_sorted_policy_df.drop_duplicates(subset='Country_id', keep='last')
last_date_df.head()
# Out:
#                                Country Country_id          Policy_type  \
# 296                              Aruba        ABW             COMPLETE
# 1017                       Afghanistan        AFG              PARTIAL
# 1252                            Angola        AGO              PARTIAL
# 299                           Anguilla        AIA             COMPLETE
# 423                      Åland Islands        ALA             COMPLETE
# 884                            Albania        ALB              PARTIAL
# 1265                           Andorra        AND  NOPOLICYIMPLEMENTED
# 511               United Arab Emirates        ARE              PARTIAL
# 1095                         Argentina        ARG              PARTIAL
# 888                            Armenia        ARM              PARTIAL
# 244                     American Samoa        ASM             COMPLETE
# 1264                        Antarctica        ATA  NOPOLICYIMPLEMENTED
# 300                Antigua and Barbuda        ATG             COMPLETE
# 272                          Australia        AUS             COMPLETE
# 969                            Austria        AUT              PARTIAL
# 1070                        Azerbaijan        AZE              PARTIAL
# 1197                           Burundi        BDI              PARTIAL
# 971                            Belgium        BEL              PARTIAL
# 972                              Benin        BEN              PARTIAL
# 433   Bonaire, Sint Eustatius and Saba        BES             COMPLETE
#
#         Policy_subtype Policy_start_date  Air_ban Air_ban_type  \
# 296   SPECIFIC_COUNTRY        2020-07-10        0    no policy
# 1017    BORDER_CLOSURE        2020-03-24        1     Specific
# 1252    BORDER_CLOSURE        2020-10-19        1     Specific
# 299   SPECIFIC_COUNTRY        2020-07-12        0    no policy
# 423         WORK_EXCEP        2020-11-19        0    no policy
# 884     BORDER_CLOSURE        2020-03-24        0    no policy
# 1265              NONE        2001-01-01        0    no policy
# 511           VISA_BAN        2020-04-03        0    no policy
# 1095    BORDER_CLOSURE        2020-11-01        1     Specific
# 888     BORDER_CLOSURE        2020-03-24        1     Specific
# 244      CITIZEN_EXCEP        2020-12-01        0    no policy
# 1264              NONE        2001-01-01        0    no policy
# 300   SPECIFIC_COUNTRY        2020-04-23        0    no policy
# 272   SPECIFIC_COUNTRY        2020-10-16        0    no policy
# 969     BORDER_CLOSURE        2020-03-19        0    no policy
# 1070    BORDER_CLOSURE        2020-08-29        1          All
# 1197    BORDER_CLOSURE        2021-01-11        0    no policy
# 971     BORDER_CLOSURE        2020-04-15        1     Specific
# 972     BORDER_CLOSURE        2020-04-17        0    no policy
# 433         WORK_EXCEP        2020-11-20        0    no policy
#
#                                            Air_ban_info  Land_ban  \
# 296                                           no policy         0
# 1017  all commercial flights suspended except for so...         0
# 1252  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 299                                           no policy         0
# 423                                           no policy         0
# 884                                           no policy         0
# 1265                                          no policy         0
# 511                                           no policy         0
# 1095                       Only citizens allowed to fly         0
# 888   Australia, Canada, China, EU member states, Ge...         0
# 244                                           no policy         0
# 1264                                          no policy         0
# 300                                           no policy         0
# 272                                           no policy         0
# 969                                           no policy         1
# 1070                                          no policy         0
# 1197                                          no policy         1
# 971   All countries except Austria, Belgium, Bulgari...         0
# 972                                           no policy         1
# 433                                           no policy         0
#
#      Land_ban_type      Land_ban_info  Sea_ban Sea_ban_type  \
# 296      no policy          no policy        0    no policy
# 1017     no policy          no policy        0    no policy
# 1252           All          no policy        1          All
# 299      no policy          no policy        0    no policy
# 423      no policy          no policy        0    no policy
# 884      no policy          no policy        1     Specific
# 1265     no policy          no policy        0    no policy
# 511      no policy          no policy        0    no policy
# 1095     no policy          no policy        0    no policy
# 888      no policy          no policy        0    no policy
# 244      no policy          no policy        0    no policy
# 1264     no policy          no policy        0    no policy
# 300      no policy          no policy        0    no policy
# 272      no policy          no policy        0    no policy
# 969       Specific  Hungary, Slovenia        0    no policy
# 1070     no policy          no policy        0    no policy
# 1197           All          no policy        1          All
# 971      no policy          no policy        0    no policy
# 972       Specific               Togo        0    no policy
# 433      no policy          no policy        0    no policy
#
#                                            Sea_ban_info  Citizen_ban  \
# 296                                           no policy            0
# 1017                                          no policy            0
# 1252                                          no policy            0
# 299                                           no policy            0
# 423                                           no policy            0
# 884   All ferries to/from Italy & other red areas ar...            0
# 1265                                          no policy            0
# 511                                           no policy            0
# 1095                                          no policy            0
# 888                                           no policy            0
# 244                                           no policy            0
# 1264                                          no policy            0
# 300                                           no policy            0
# 272                                           no policy            0
# 969                                           no policy            0
# 1070                                          no policy            0
# 1197                                          no policy            0
# 971                                           no policy            0
# 972                                           no policy            0
# 433                                           no policy            0
#
#      Citizen_ban_info  Travel_history_ban Travel_history_ban_info  \
# 296         no policy                   0               no policy
# 1017        no policy                   0               no policy
# 1252        no policy                   0               no policy
# 299         no policy                   0               no policy
# 423         no policy                   0               no policy
# 884         no policy                   0               no policy
# 1265        no policy                   0               no policy
# 511         no policy                   0               no policy
# 1095        no policy                   0               no policy
# 888         no policy                   0               no policy
# 244         no policy                   0               no policy
# 1264        no policy                   0               no policy
# 300         no policy                   0               no policy
# 272         no policy                   0               no policy
# 969         no policy                   0               no policy
# 1070        no policy                   0               no policy
# 1197        no policy                   0               no policy
# 971         no policy                   0               no policy
# 972         no policy                   0               no policy
# 433         no policy                   0               no policy
#
#       Refugee_ban Refugee_ban_info  Visa_ban Visa_ban_list  \
# 296             0        no policy         0     no policy
# 1017            0        no policy         0     no policy
# 1252            0        no policy         0     no policy
# 299             0        no policy         0     no policy
# 423             0        no policy         0     no policy
# 884             0        no policy         0     no policy
# 1265            0        no policy         0     no policy
# 511             0        no policy         1      specific
# 1095            0        no policy         0     no policy
# 888             0        no policy         0     no policy
# 244             0        no policy         0     no policy
# 1264            0        no policy         0     no policy
# 300             0        no policy         0     no policy
# 272             0        no policy         0     no policy
# 969             0        no policy         0     no policy
# 1070            0        no policy         0     no policy
# 1197            0        no policy         0     no policy
# 971             0        no policy         0     no policy
# 972             0        no policy         0     no policy
# 433             0        no policy         0     no policy
#
#                                          Visa_ban_info  Citizen_exceptions  \
# 296                                          no policy                   1
# 1017                                         no policy                   0
# 1252                                         no policy                   0
# 299                                          no policy                   1
# 423                                          no policy                   1
# 884                                          no policy                   0
# 1265                                         no policy                   0
# 511   New visa seekers and existing valid visa holders                   0
# 1095                                         no policy                   0
# 888                                          no policy                   0
# 244                                          no policy                   1
# 1264                                         no policy                   0
# 300                                          no policy                   0
# 272                                          no policy                   1
# 969                                          no policy                   0
# 1070                                         no policy                   0
# 1197                                         no policy                   0
# 971                                          no policy                   0
# 972                                          no policy                   0
# 433                                          no policy                   1
#
#                                 Citizen_exceptions_info  Country_exceptions  \
# 296   residents with prior authorization, non-reside...                   1
# 1017                                          no policy                   0
# 1252                                          no policy                   0
# 299                                 citizens, residents                   1
# 423   nationals of Finland, family members of nation...                   1
# 884                                           no policy                   0
# 1265                                          no policy                   0
# 511                                           no policy                   0
# 1095                                          no policy                   0
# 888                                           no policy                   0
# 244                                            citizens                   0
# 1264                                          no policy                   0
# 300                                           no policy                   1
# 272   Australian Citizens, permanent residents in Au...                   1
# 969                                           no policy                   0
# 1070                                          no policy                   0
# 1197                                          no policy                   0
# 971                                           no policy                   0
# 972                                           no policy                   0
# 433                       citizens, permanent residents                   1
#
#                                 Country_exceptions_info  Work_exceptions
# 296   Antiga and Barbuda, The Bahamas, Barbados, Cub...                0
# 1017                                          no policy                0
# 1252                                          no policy                0
# 299   Aruba, Bonaire, St Eustatius and Saba, Belize,...                0
# 423   Vactican City, Australia, South Korea, Japan, ...                1
# 884                                           no policy                0
# 1265                                          no policy                0
# 511                                           no policy                0
# 1095                                          no policy                0
# 888                                           no policy                0
# 244                                           no policy                0
# 1264                                          no policy                0
# 300                                  Dominican Republic                0
# 272   New Zealand (quarantine free travel if people ...                0
# 969                                           no policy                0
# 1070                                          no policy                0
# 1197                                          no policy                0
# 971                                           no policy                0
# 972                                           no policy                0
# 433   Saba, Antiga, Anguilla, Montserrat, Saint Vinc...                1

# %%
# len of df
len(last_date_df)
# Out:
# 243

# %%
# showing cols of df
last_date_df.columns
# Out:
# Index(['Country', 'Country_id', 'Policy_type', 'Policy_subtype',
#        'Policy_start_date', 'Air_ban', 'Air_ban_type', 'Air_ban_info',
#        'Land_ban', 'Land_ban_type', 'Land_ban_info', 'Sea_ban', 'Sea_ban_type',
#        'Sea_ban_info', 'Citizen_ban', 'Citizen_ban_info', 'Travel_history_ban',
#        'Travel_history_ban_info', 'Refugee_ban', 'Refugee_ban_info',
#        'Visa_ban', 'Visa_ban_list', 'Visa_ban_info', 'Citizen_exceptions',
#        'Citizen_exceptions_info', 'Country_exceptions',
#        'Country_exceptions_info', 'Work_exceptions'],
#       dtype='object')

# %%
# separating out only rows where a complete ban was in effect, saving only cols that apply
full_closures_df = last_date_df[last_date_df['Policy_type'] == 'COMPLETE'][['Country', 'Country_id', 'Policy_type', 'Policy_subtype', 
                                                                            'Policy_start_date', 'Citizen_exceptions', 'Citizen_exceptions_info', 
                                                                            'Country_exceptions',        'Country_exceptions_info', 'Work_exceptions']]
full_closures_df.reset_index(inplace=True, drop=True)
full_closures_df.head()
# Out:
#                Country Country_id Policy_type    Policy_subtype  \
# 0                Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY
# 1             Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY
# 2        Åland Islands        ALA    COMPLETE        WORK_EXCEP
# 3       American Samoa        ASM    COMPLETE     CITIZEN_EXCEP
# 4  Antigua and Barbuda        ATG    COMPLETE  SPECIFIC_COUNTRY
#
#   Policy_start_date  Citizen_exceptions  \
# 0        2020-07-10                   1
# 1        2020-07-12                   1
# 2        2020-11-19                   1
# 3        2020-12-01                   1
# 4        2020-04-23                   0
#
#                              Citizen_exceptions_info  Country_exceptions  \
# 0  residents with prior authorization, non-reside...                   1
# 1                                citizens, residents                   1
# 2  nationals of Finland, family members of nation...                   1
# 3                                           citizens                   0
# 4                                          no policy                   1
#
#                              Country_exceptions_info  Work_exceptions
# 0  Antiga and Barbuda, The Bahamas, Barbados, Cub...                0
# 1  Aruba, Bonaire, St Eustatius and Saba, Belize,...                0
# 2  Vactican City, Australia, South Korea, Japan, ...                1
# 3                                          no policy                0
# 4                                 Dominican Republic                0

# %%
# separating out only rows where a partial ban was in effect, saving only cols that apply
partial_closures_df = last_date_df[last_date_df['Policy_type'] == 'PARTIAL'][['Country', 'Country_id', 'Policy_type', 'Policy_subtype',
       'Policy_start_date', 'Air_ban', 'Air_ban_type', 'Air_ban_info',
       'Land_ban', 'Land_ban_type', 'Land_ban_info', 'Sea_ban', 'Sea_ban_type',
       'Sea_ban_info', 'Citizen_ban', 'Citizen_ban_info', 'Travel_history_ban',
       'Travel_history_ban_info', 'Refugee_ban', 'Refugee_ban_info',
       'Visa_ban', 'Visa_ban_list', 'Visa_ban_info']]
partial_closures_df.reset_index(inplace=True, drop=True)
partial_closures_df.head()
# Out:
#                 Country Country_id Policy_type  Policy_subtype  \
# 0           Afghanistan        AFG     PARTIAL  BORDER_CLOSURE
# 1                Angola        AGO     PARTIAL  BORDER_CLOSURE
# 2               Albania        ALB     PARTIAL  BORDER_CLOSURE
# 3  United Arab Emirates        ARE     PARTIAL        VISA_BAN
# 4             Argentina        ARG     PARTIAL  BORDER_CLOSURE
#
#   Policy_start_date  Air_ban Air_ban_type  \
# 0        2020-03-24        1     Specific
# 1        2020-10-19        1     Specific
# 2        2020-03-24        0    no policy
# 3        2020-04-03        0    no policy
# 4        2020-11-01        1     Specific
#
#                                         Air_ban_info  Land_ban Land_ban_type  \
# 0  all commercial flights suspended except for so...         0     no policy
# 1  Afghanistan, Aland Islands, Albania, Algeria, ...         1           All
# 2                                          no policy         0     no policy
# 3                                          no policy         0     no policy
# 4                       Only citizens allowed to fly         0     no policy
#
#   Land_ban_info  Sea_ban Sea_ban_type  \
# 0     no policy        0    no policy
# 1     no policy        1          All
# 2     no policy        1     Specific
# 3     no policy        0    no policy
# 4     no policy        0    no policy
#
#                                         Sea_ban_info  Citizen_ban  \
# 0                                          no policy            0
# 1                                          no policy            0
# 2  All ferries to/from Italy & other red areas ar...            0
# 3                                          no policy            0
# 4                                          no policy            0
#
#   Citizen_ban_info  Travel_history_ban Travel_history_ban_info  Refugee_ban  \
# 0        no policy                   0               no policy            0
# 1        no policy                   0               no policy            0
# 2        no policy                   0               no policy            0
# 3        no policy                   0               no policy            0
# 4        no policy                   0               no policy            0
#
#   Refugee_ban_info  Visa_ban Visa_ban_list  \
# 0        no policy         0     no policy
# 1        no policy         0     no policy
# 2        no policy         0     no policy
# 3        no policy         1      specific
# 4        no policy         0     no policy
#
#                                       Visa_ban_info
# 0                                         no policy
# 1                                         no policy
# 2                                         no policy
# 3  New visa seekers and existing valid visa holders
# 4                                         no policy

# %%
# separating out only rows where no ban was in effect, saving only cols that apply
no_closures_df = last_date_df[last_date_df['Policy_type'] == 'NOPOLICYIMPLEMENTED'][['Country', 'Country_id', 'Policy_type', 'Policy_subtype']]
no_closures_df.reset_index(inplace=True, drop=True)
no_closures_df.head(10)
# Out:
#        Country Country_id          Policy_type Policy_subtype
# 0      Andorra        AND  NOPOLICYIMPLEMENTED           NONE
# 1   Antarctica        ATA  NOPOLICYIMPLEMENTED           NONE
# 2     Guernsey        GGY  NOPOLICYIMPLEMENTED           NONE
# 3         Guam        GUM  NOPOLICYIMPLEMENTED           NONE
# 4       Jersey        JEY  NOPOLICYIMPLEMENTED           NONE
# 5    Nicaragua        NIC  NOPOLICYIMPLEMENTED           NONE
# 6  Puerto Rico        PRI  NOPOLICYIMPLEMENTED           NONE
# 7   San Marino        SMR  NOPOLICYIMPLEMENTED           NONE

# %%
# checking lengths of the 3 dfs
len(full_closures_df), len(partial_closures_df), len(no_closures_df)
# Out:
# (108, 127, 8)

# %%
# creation of policy table
# lists of policy types, subtypes and ids
full_policy_subtypes_list = [x for x in full_closures_df['Policy_subtype'].unique()]
full_policy_types_list = ['Full' for x in full_closures_df['Policy_subtype'].unique()]
full_policy_ids_list = [f'F{x}' for x in range(1, len(full_policy_types_list)+1)]

partial_policy_subtypes_list = [x for x in partial_closures_df['Policy_subtype'].unique()]
partial_policy_types_list = ['Partial' for x in partial_closures_df['Policy_subtype'].unique()]
partial_policy_ids_list = [f'P{x}' for x in range(1, len(partial_policy_types_list)+1)]

no_policy_subtypes_list = [x for x in no_closures_df['Policy_subtype'].unique()]
no_policy_types_list = ['None' for x in no_closures_df['Policy_subtype'].unique()]
no_policy_ids_list = [f'N{x}' for x in range(1, len(no_policy_types_list)+1)]

all_policy_subtypes_list = full_policy_subtypes_list + partial_policy_subtypes_list + no_policy_subtypes_list
all_policy_types_list = full_policy_types_list + partial_policy_types_list + no_policy_types_list
policy_id_list = full_policy_ids_list + partial_policy_ids_list + no_policy_ids_list
all_policy_types_list, all_policy_subtypes_list, policy_id_list
# Out:
# (['Full',
#   'Full',
#   'Full',
#   'Full',
#   'Partial',
#   'Partial',
#   'Partial',
#   'Partial',
#   'None'],
#  ['SPECIFIC_COUNTRY',
#   'WORK_EXCEP',
#   'CITIZEN_EXCEP',
#   'ESSENTIAL_ONLY',
#   'BORDER_CLOSURE',
#   'VISA_BAN',
#   'CITIZENSHIP_BAN',
#   'HISTORY_BAN',
#   'NONE'],
#  ['F1', 'F2', 'F3', 'F4', 'P1', 'P2', 'P3', 'P4', 'N1'])

# %%
# creation of policy table
# creating df out of lists
policy_types_df = pd.DataFrame({
    'Policy_id': policy_id_list, 'Policy_type': all_policy_types_list, 'Policy_subtype': all_policy_subtypes_list})
policy_types_df
# Out:
#   Policy_id Policy_type    Policy_subtype
# 0        F1        Full  SPECIFIC_COUNTRY
# 1        F2        Full        WORK_EXCEP
# 2        F3        Full     CITIZEN_EXCEP
# 3        F4        Full    ESSENTIAL_ONLY
# 4        P1     Partial    BORDER_CLOSURE
# 5        P2     Partial          VISA_BAN
# 6        P3     Partial   CITIZENSHIP_BAN
# 7        P4     Partial       HISTORY_BAN
# 8        N1        None              NONE

# %%
# full closures -- country exceptions
full_country_df = pd.DataFrame(
    full_closures_df[full_closures_df['Country_exceptions'] == 1][['Country_id', 'Policy_start_date', 'Country_exceptions_info']]
)
full_country_df['Policy_id'] = 'F1'

# full closures -- work exceptions --! no further info on this closure type (no info col)
full_work_df = pd.DataFrame(
    full_closures_df[full_closures_df['Work_exceptions'] == 1][['Country_id', 'Policy_start_date']]
)
full_work_df['Policy_id'] = 'F2'

# full closures -- citizen exceptions
full_citizens_df = pd.DataFrame(
    full_closures_df[full_closures_df['Citizen_exceptions'] == 1][['Country_id', 'Policy_start_date', 'Citizen_exceptions_info']]
)
full_citizens_df['Policy_id'] = 'F3'

# full closures -- essential only --! no further info on this closure type (no info col)
full_essential_df = pd.DataFrame(
    full_closures_df[full_closures_df['Policy_subtype'] == 'ESSENTIAL_ONLY'][['Country_id', 'Policy_start_date']]
)
full_essential_df['Policy_id'] = 'F4'

# %%
# partial closure -- border closure
# by this point refugee bans are no longer in the dataframe (bans have ended by that time point) 
# split further into air, land, sea
partial_borders_df = pd.DataFrame(
    partial_closures_df[partial_closures_df['Policy_subtype'] == 'BORDER_CLOSURE'][[
        'Country_id', 'Policy_start_date', 'Air_ban', 'Air_ban_type', 'Air_ban_info', 
        'Land_ban', 'Land_ban_type', 'Land_ban_info', 'Sea_ban', 'Sea_ban_type', 'Sea_ban_info']]
)
partial_borders_df['Policy_id'] = 'P1'
# # partial -- air
partial_air_df = pd.DataFrame(partial_borders_df[partial_borders_df['Air_ban'] == 1][[
    'Country_id', 'Policy_start_date', 'Air_ban', 'Air_ban_type', 'Air_ban_info', 'Policy_id']])
# # partial -- sea
partial_sea_df = pd.DataFrame(partial_borders_df[partial_borders_df['Sea_ban'] == 1][[
    'Country_id', 'Policy_start_date', 'Sea_ban', 'Sea_ban_type', 'Sea_ban_info', 'Policy_id']])
# # partial -- land
partial_land_df = pd.DataFrame(partial_borders_df[partial_borders_df['Land_ban'] == 1][[
    'Country_id', 'Policy_start_date', 'Land_ban', 'Land_ban_type', 'Land_ban_info', 'Policy_id']])

# partial closure -- visa ban
partial_visa_df = pd.DataFrame(
    partial_closures_df[partial_closures_df['Policy_subtype'] == 'VISA_BAN'][[
        'Country_id', 'Policy_start_date', 'Visa_ban', 'Visa_ban_list', 'Visa_ban_info']]
)
partial_visa_df['Policy_id'] = 'P2'

# partial closure -- citizenship ban
partial_citizenship_df = pd.DataFrame(
    partial_closures_df[partial_closures_df['Policy_subtype'] == 'CITIZENSHIP_BAN'][[
        'Country_id', 'Policy_start_date', 'Citizen_ban', 'Citizen_ban_info']]
)
partial_citizenship_df['Policy_id'] = 'P3'

# partial closure -- history ban
partial_history_df = pd.DataFrame(
    partial_closures_df[partial_closures_df['Policy_subtype'] == 'HISTORY_BAN'][[
        'Country_id', 'Policy_start_date', 'Travel_history_ban', 'Travel_history_ban_info']]
)
partial_history_df['Policy_id'] = 'P4'

partial_history_df.sample(5)
# Out:
#     Country_id Policy_start_date  Travel_history_ban  \
# 37         GBR        2020-11-13                   1
# 108        SYR        2020-04-10                   1
# 97         SAU        2020-06-24                   1
# 116        TUV        2020-03-15                   1
# 69         MDA        2020-12-07                   1
#
#                                Travel_history_ban_info Policy_id
# 37                                             Denmark        P4
# 108  Australia, Belgium, China, Denmark, Finland, F...        P4
# 97   Expatriate residents currently abroad are not ...        P4
# 116                                              China        P4
# 69   Albania, Andorra, Argentina, Armenia, Austria,...        P4

# %%
# no closures, adding the policy type
no_closures_df['Policy_id'] = 'N1'
no_closures_df = no_closures_df[['Country_id', 'Policy_id']]
no_closures_df.head()
# Out:
#   Country_id Policy_id
# 0        AND        N1
# 1        ATA        N1
# 2        GGY        N1
# 3        GUM        N1
# 4        JEY        N1

# %%
# reading in csvs
vaccinations_df = pd.read_csv('Clean/vaccinations_cleaned.csv')
travel_df = pd.read_csv('Clean/travel_restrictions_clean.csv')

# %%
# number of countries in each df - travel restrictions has the most
len(vaccinations_df['Country'].unique()), len(travel_df['Country'].unique()), len(last_date_df['Country'].unique())
# Out:
# (58, 267, 243)

# %%
# creating a countries names and ids table
# subsetting each CSV source df for only country names and IDs
vacc_countries_df = vaccinations_df[['Country', 'Country_id']]
immig_countries_df = last_date_df[['Country', 'Country_id']]
travel_countries_df = travel_df[['Country', 'Country_id']]

# outer merging the travel restrictions and immigration restriction dfs 
# to capture country names not in the other table
first_countries_merge = travel_countries_df.merge(immig_countries_df, how='outer', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
print(len(first_countries_merge))

# outer merging the vaccinations and first merge dfs
# to capture country names not in the other table
full_merge = first_countries_merge.merge(vacc_countries_df, how='outer', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
print(len(full_merge))
full_merge.head()
# Out:
# 270
# 271
#                             Country Country_id
# 0                          Kiribati        KIR
# 1                            Kosovo        RKS
# 2                            Kuwait        KWT
# 3                        Kyrgyzstan        KGZ
# 4  Lao People's Democratic Republic        LAO

# %%
# checking to see if there are any duplicates in the merged tables -- there aren't
full_merge[full_merge.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Country, Country_id]
# Index: []

# %%
# making the table alphabetical, resetting the index, saving to a new descriptive name
countries_names_ids_df = full_merge.sort_values('Country').reset_index(drop=True)
countries_names_ids_df.head()
# Out:
#           Country Country_id
# 0     Afghanistan        AFG
# 1         Albania        ALB
# 2         Algeria        DZA
# 3  American Samoa        ASM
# 4         Andorra        AND

# %%
# doing first merge w/ each of the 3 closure dfs, w/ the travel restrictions df
full_closures_merged = full_closures_df.merge(travel_df, how='inner', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
full_closures_merged.head()
# Out:
#                Country Country_id Policy_type    Policy_subtype  \
# 0                Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY
# 1             Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY
# 2        Åland Islands        ALA    COMPLETE        WORK_EXCEP
# 3       American Samoa        ASM    COMPLETE     CITIZEN_EXCEP
# 4  Antigua and Barbuda        ATG    COMPLETE  SPECIFIC_COUNTRY
#
#   Policy_start_date  Citizen_exceptions  \
# 0        2020-07-10                   1
# 1        2020-07-12                   1
# 2        2020-11-19                   1
# 3        2020-12-01                   1
# 4        2020-04-23                   0
#
#                              Citizen_exceptions_info  Country_exceptions  \
# 0  residents with prior authorization, non-reside...                   1
# 1                                citizens, residents                   1
# 2  nationals of Finland, family members of nation...                   1
# 3                                           citizens                   0
# 4                                          no policy                   1
#
#                              Country_exceptions_info  Work_exceptions  \
# 0  Antiga and Barbuda, The Bahamas, Barbados, Cub...                0
# 1  Aruba, Bonaire, St Eustatius and Saba, Belize,...                0
# 2  Vactican City, Australia, South Korea, Japan, ...                1
# 3                                          no policy                0
# 4                                 Dominican Republic                0
#
#                                      Quarantine_type
# 0  Self-isolation at own accommodation- subject t...
# 1  Quarantine at government designated site or Go...
# 2                                            Unknown
# 3  Quarantine Requirement outside territory. <br>...
# 4  Quarantine requirement at government designate...

# %%
# doing first merge w/ each of the 3 closure dfs, w/ the travel restrictions df
partial_closures_merged = partial_closures_df.merge(travel_df, how='inner', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
partial_closures_merged.head()
# Out:
#                 Country Country_id Policy_type  Policy_subtype  \
# 0           Afghanistan        AFG     PARTIAL  BORDER_CLOSURE
# 1                Angola        AGO     PARTIAL  BORDER_CLOSURE
# 2               Albania        ALB     PARTIAL  BORDER_CLOSURE
# 3  United Arab Emirates        ARE     PARTIAL        VISA_BAN
# 4             Argentina        ARG     PARTIAL  BORDER_CLOSURE
#
#   Policy_start_date  Air_ban  \
# 0        2020-03-24        1
# 1        2020-10-19        1
# 2        2020-03-24        0
# 3        2020-04-03        0
# 4        2020-11-01        1
#
#                                         Air_ban_info  Land_ban Land_ban_info  \
# 0  all commercial flights suspended except for so...         0     no policy
# 1  Afghanistan, Aland Islands, Albania, Algeria, ...         1     no policy
# 2                                          no policy         0     no policy
# 3                                          no policy         0     no policy
# 4                       Only citizens allowed to fly         0     no policy
#
#    Sea_ban                                       Sea_ban_info  Citizen_ban  \
# 0        0                                          no policy            0
# 1        1                                          no policy            0
# 2        1  All ferries to/from Italy & other red areas ar...            0
# 3        0                                          no policy            0
# 4        0                                          no policy            0
#
#   Citizen_ban_info  Travel_history_ban Travel_history_ban_info  Refugee_ban  \
# 0        no policy                   0               no policy            0
# 1        no policy                   0               no policy            0
# 2        no policy                   0               no policy            0
# 3        no policy                   0               no policy            0
# 4        no policy                   0               no policy            0
#
#   Refugee_ban_info  Visa_ban  \
# 0        no policy         0
# 1        no policy         0
# 2        no policy         0
# 3        no policy         1
# 4        no policy         0
#
#                                       Visa_ban_info  \
# 0                                         no policy
# 1                                         no policy
# 2                                         no policy
# 3  New visa seekers and existing valid visa holders
# 4                                         no policy
#
#                                      Quarantine_type
# 0  No declared requirements.<br>\n\nThere are cur...
# 1  Quarantine requirement at government designate...
# 2  Self Isolation- subject to origin.<br>\n\nTher...
# 3  Self-isolation at own accommodation.\n\nString...
# 4  Self-isolation at own accommodation.\n\nAll tr...

# %%
# doing first merge w/ each of the 3 closure dfs, w/ the travel restrictions df
no_closures_merged = no_closures_df.merge(travel_df, how='inner', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
no_closures_merged.head()
# Out:
#       Country Country_id          Policy_type Policy_subtype  \
# 0     Andorra        AND  NOPOLICYIMPLEMENTED           NONE
# 1  Antarctica        ATA  NOPOLICYIMPLEMENTED           NONE
# 2    Guernsey        GGY  NOPOLICYIMPLEMENTED           NONE
# 3        Guam        GUM  NOPOLICYIMPLEMENTED           NONE
# 4      Jersey        JEY  NOPOLICYIMPLEMENTED           NONE
#
#                                      Quarantine_type
# 0  Home isolation is required until COVID test re...
# 1                                            Unknown
# 2                                            Unknown
# 3  Quarantine Requirement- Unknown where\nPasseng...
# 4                                            Unknown

# %%
# doing second merge w/ each of the 3 closure dfs, with vaccination data
full_closures_all = full_closures_df.merge(vaccinations_df, how='left', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
full_closures_all.sample(5)
# Out:
#      Country Country_id Policy_type    Policy_subtype Policy_start_date  \
# 59   Morocco        MAR    COMPLETE     CITIZEN_EXCEP        2020-07-15
# 7   Bulgaria        BGR    COMPLETE  SPECIFIC_COUNTRY        2020-07-16
# 1   Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY        2020-07-12
# 9    Bahamas        BHS    COMPLETE    ESSENTIAL_ONLY        2020-03-24
# 27  Dominica        DMA    COMPLETE     CITIZEN_EXCEP        2020-04-16
#
#     Citizen_exceptions        Citizen_exceptions_info  Country_exceptions  \
# 59                   1           Citizens, Residents                    0
# 7                    1            citizens, residents                   1
# 1                    1            citizens, residents                   1
# 9                    0                      no policy                   0
# 27                   1  citizens, permanent residents                   0
#
#                               Country_exceptions_info  Work_exceptions  \
# 59                                          no policy                0
# 7   The Republic of Austria, The Kingdom of Nether...                0
# 1   Aruba, Bonaire, St Eustatius and Saba, Belize,...                0
# 9                                           no policy                0
# 27                                          no policy                0
#
#    vaccination_date  total_vaccinations  avg_daily_vaccinations
# 59              NaN                 NaN                     NaN
# 7        2021-01-26             29122.0             1008.413793
# 1               NaN                 NaN                     NaN
# 9               NaN                 NaN                     NaN
# 27              NaN                 NaN                     NaN

# %%
# doing second merge w/ each of the 3 closure dfs, with vaccination data
partial_closures_all = partial_closures_df.merge(vaccinations_df, how='left', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
partial_closures_all.sample(5)
# Out:
#      Country Country_id Policy_type  Policy_subtype Policy_start_date  \
# 82      Niue        NIU     PARTIAL  BORDER_CLOSURE        2020-03-20
# 19     China        CHN     PARTIAL        VISA_BAN        2020-09-23
# 91  Paraguay        PRY     PARTIAL  BORDER_CLOSURE        2020-08-05
# 44    Guyana        GUY     PARTIAL  BORDER_CLOSURE        2020-03-27
# 9    Belgium        BEL     PARTIAL  BORDER_CLOSURE        2020-04-15
#
#     Air_ban                                       Air_ban_info  Land_ban  \
# 82        1  Passengers who have been in Australia, Austria...         1
# 19        0                                          no policy         0
# 91        1                                          no policy         0
# 44        0                                          no policy         1
# 9         1  All countries except Austria, Belgium, Bulgari...         0
#
#                                         Land_ban_info  Sea_ban  \
# 82  Passengers who have been in Australia, Austria...        1
# 19                                          no policy        0
# 91                                          no policy        0
# 44                                          no policy        0
# 9                                           no policy        0
#
#                                          Sea_ban_info  Citizen_ban  \
# 82  Passengers who have been in Australia, Austria...            0
# 19                                          no policy            0
# 91                                          no policy            0
# 44                                          no policy            0
# 9                                           no policy            0
#
#    Citizen_ban_info  Travel_history_ban Travel_history_ban_info  Refugee_ban  \
# 82        no policy                   0               no policy            0
# 19        no policy                   0               no policy            0
# 91        no policy                   0               no policy            0
# 44        no policy                   0               no policy            0
# 9         no policy                   0               no policy            0
#
#    Refugee_ban_info  Visa_ban Visa_ban_info vaccination_date  \
# 82        no policy         0     no policy              NaN
# 19        no policy         1     no policy       2021-01-20
# 91        no policy         0     no policy              NaN
# 44        no policy         0     no policy              NaN
# 9         no policy         0     no policy       2021-01-25
#
#     total_vaccinations  avg_daily_vaccinations
# 82                 NaN                     NaN
# 19          15000000.0           322152.513514
# 91                 NaN                     NaN
# 44                 NaN                     NaN
# 9             213301.0             6503.103448

# %%
# doing second merge w/ each of the 3 closure dfs, with vaccination data
no_closures_all = no_closures_df.merge(vaccinations_df, how='left', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
no_closures_all.head(10)
# Out:
#        Country Country_id          Policy_type Policy_subtype  \
# 0      Andorra        AND  NOPOLICYIMPLEMENTED           NONE
# 1   Antarctica        ATA  NOPOLICYIMPLEMENTED           NONE
# 2     Guernsey        GGY  NOPOLICYIMPLEMENTED           NONE
# 3         Guam        GUM  NOPOLICYIMPLEMENTED           NONE
# 4       Jersey        JEY  NOPOLICYIMPLEMENTED           NONE
# 5    Nicaragua        NIC  NOPOLICYIMPLEMENTED           NONE
# 6  Puerto Rico        PRI  NOPOLICYIMPLEMENTED           NONE
# 7   San Marino        SMR  NOPOLICYIMPLEMENTED           NONE
#
#   vaccination_date  total_vaccinations  avg_daily_vaccinations
# 0              NaN                 NaN                     NaN
# 1              NaN                 NaN                     NaN
# 2              NaN                 NaN                     NaN
# 3              NaN                 NaN                     NaN
# 4              NaN                 NaN                     NaN
# 5              NaN                 NaN                     NaN
# 6              NaN                 NaN                     NaN
# 7              NaN                 NaN                     NaN

# %%
# checking which cols have null values
# replacing nulls (only in vaccination sourced data cols) with 'no information'
# re-checking null values - none left
print(full_closures_all.isnull().sum(), partial_closures_all.isnull().sum(), no_closures_all.isnull().sum())
full_closures_all.fillna('no information', inplace=True)
partial_closures_all.fillna('no information', inplace=True)
no_closures_all.fillna('no information', inplace=True)
full_closures_all.isnull().sum(), partial_closures_all.isnull().sum(), no_closures_all.isnull().sum()
# Out:
# Country                     0
# Country_id                  0
# Policy_type                 0
# Policy_subtype              0
# Policy_start_date           0
# Citizen_exceptions          0
# Citizen_exceptions_info     0
# Country_exceptions          0
# Country_exceptions_info     0
# Work_exceptions             0
# vaccination_date           84
# total_vaccinations         84
# avg_daily_vaccinations     84
# dtype: int64 Country                     0
# Country_id                  0
# Policy_type                 0
# Policy_subtype              0
# Policy_start_date           0
# Air_ban                     0
# Air_ban_info                0
# Land_ban                    0
# Land_ban_info               0
# Sea_ban                     0
# Sea_ban_info                0
# Citizen_ban                 0
# Citizen_ban_info            0
# Travel_history_ban          0
# Travel_history_ban_info     0
# Refugee_ban                 0
# Refugee_ban_info            0
# Visa_ban                    0
# Visa_ban_info               0
# vaccination_date           95
# total_vaccinations         95
# avg_daily_vaccinations     95
# dtype: int64 Country                   0
# Country_id                0
# Policy_type               0
# Policy_subtype            0
# vaccination_date          8
# total_vaccinations        8
# avg_daily_vaccinations    8
# dtype: int64
# (Country                    0
#  Country_id                 0
#  Policy_type                0
#  Policy_subtype             0
#  Policy_start_date          0
#  Citizen_exceptions         0
#  Citizen_exceptions_info    0
#  Country_exceptions         0
#  Country_exceptions_info    0
#  Work_exceptions            0
#  vaccination_date           0
#  total_vaccinations         0
#  avg_daily_vaccinations     0
#  dtype: int64,
#  Country                    0
#  Country_id                 0
#  Policy_type                0
#  Policy_subtype             0
#  Policy_start_date          0
#  Air_ban                    0
#  Air_ban_info               0
#  Land_ban                   0
#  Land_ban_info              0
#  Sea_ban                    0
#  Sea_ban_info               0
#  Citizen_ban                0
#  Citizen_ban_info           0
#  Travel_history_ban         0
#  Travel_history_ban_info    0
#  Refugee_ban                0
#  Refugee_ban_info           0
#  Visa_ban                   0
#  Visa_ban_info              0
#  vaccination_date           0
#  total_vaccinations         0
#  avg_daily_vaccinations     0
#  dtype: int64,
#  Country                   0
#  Country_id                0
#  Policy_type               0
#  Policy_subtype            0
#  vaccination_date          0
#  total_vaccinations        0
#  avg_daily_vaccinations    0
#  dtype: int64)

# %%
# replacing the now 'no information' dates with placeholder date '01-01-01' in case datetimes need to be applied
# creating lists to hold the dates
# replacing the date cols with those lists
full_closures_dates = ['01-01-01' if x == 'no information' else x for x in full_closures_all['vaccination_date']]
partial_closures_dates = ['01-01-01' if x == 'no information' else x for x in partial_closures_all['vaccination_date']]
no_closures_dates = ['01-01-01' if x == 'no information' else x for x in no_closures_all['vaccination_date']]

full_closures_all['vaccination_date'] = full_closures_dates
partial_closures_all['vaccination_date'] = partial_closures_dates
no_closures_all['vaccination_date'] = no_closures_dates

# %%
# exporting all policies df to csv
last_date_df.to_csv('Clean/policy_cleaned.csv', index=False)

# %%
# exporting policy level specific dfs to csvs
#full_closures_all.to_csv('Clean/full_closures_df', index=False)
#partial_closures_all.to_csv('Clean/partial_closures_df', index=False)
#no_closures_all.to_csv('Clean/no_closures_df', index=False)
