# %%
# import dependencies
import pandas as pd
import datetime as dt

# %%
# attempt to increase col display
pd.set_option('display.max_columns', 28)

# %%
# read in csv
policy_df = pd.read_csv('Raw/policy_list.csv')
policy_df.head()
# Out:
#     ID                            COUNTRY_NAME ISO3 ISO2 POLICY_TYPE  \
# 0  118                       Brunei Darussalam  BRN   BN    COMPLETE
# 1  259                                 Morocco  MAR   MA    COMPLETE
# 2  362  Korea, Democratic People's Republic of  PRK   KP    COMPLETE
# 3  386                        Marshall Islands  MHL   MH    COMPLETE
# 4  470        Lao People's Democratic Republic  LAO   LA    COMPLETE
#
#    POLICY_SUBTYPE START_DATE  END_DATE  AIR AIR_TYPE TARGETS_AIR  LAND  \
# 0  ESSENTIAL_ONLY   03_23_20  03_17_20    0      NaN         NaN     0
# 1  ESSENTIAL_ONLY   03_20_20      NONE    0      NaN         NaN     0
# 2  ESSENTIAL_ONLY   01_22_20      NONE    0      NaN         NaN     0
# 3  ESSENTIAL_ONLY   03_08_20  09_05_20    0      NaN         NaN     0
# 4  ESSENTIAL_ONLY   03_16_20  03_21_20    0      NaN         NaN     0
#
#   LAND_TYPE TARGETS_LAND  ...  VISA_BAN VISA_BAN_TYPE VISA_BAN_LIST  \
# 0       NaN          NaN  ...         0           NaN           NaN
# 1       NaN          NaN  ...         0           NaN           NaN
# 2       NaN          NaN  ...         0           NaN           NaN
# 3       NaN          NaN  ...         0           NaN           NaN
# 4       NaN          NaN  ...         0           NaN           NaN
#
#    CITIZEN_EXCEP CITIZEN_EXCEP_LIST  COUNTRY_EXCEP COUNTRY_EXCEP_LIST  \
# 0              0                NaN              0                NaN
# 1              0                NaN              0                NaN
# 2              0                NaN              0                NaN
# 3              0                NaN              0                NaN
# 4              0                NaN              0                NaN
#
#    WORK_EXCEP                                            SOURCE0  \
# 0           0  https://web.archive.org/web/20201222164708/htt...
# 1           0  https://web.archive.org/web/20200316164353/pan...
# 2           0  https://web.archive.org/web/20200313010930/pan...
# 3           0  https://web.archive.org/web/20200504210823/htt...
# 4           0  https://web.archive.org/web/20200316164353/htt...
#
#                                              SOURCE1 SOURCE2 SOURCE3  SOURCE4  \
# 0                                                NaN     NaN     NaN      NaN
# 1  https://web.archive.org/web/20201206185016/htt...     NaN     NaN      NaN
# 2  https://web.archive.org/web/20200531000132/htt...     NaN     NaN      NaN
# 3                                                NaN     NaN     NaN      NaN
# 4                                                NaN     NaN     NaN      NaN
#
#   SOURCE5
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#
# [5 rows x 37 columns]

# %%
# viewing current columns
policy_df.columns
# Out:
# Index(['ID', 'COUNTRY_NAME', 'ISO3', 'ISO2', 'POLICY_TYPE', 'POLICY_SUBTYPE',
#        'START_DATE', 'END_DATE', 'AIR', 'AIR_TYPE', 'TARGETS_AIR', 'LAND',
#        'LAND_TYPE', 'TARGETS_LAND', 'SEA', 'SEA_TYPE', 'TARGETS_SEA',
#        'CITIZEN', 'CITIZEN_LIST', 'HISTORY_BAN', 'HISTORY_BAN_LIST', 'REFUGEE',
#        'REFUGEE_LIST', 'VISA_BAN', 'VISA_BAN_TYPE', 'VISA_BAN_LIST',
#        'CITIZEN_EXCEP', 'CITIZEN_EXCEP_LIST', 'COUNTRY_EXCEP',
#        'COUNTRY_EXCEP_LIST', 'WORK_EXCEP', 'SOURCE0', 'SOURCE1', 'SOURCE2',
#        'SOURCE3', 'SOURCE4', 'SOURCE5'],
#       dtype='object')

# %%
# taking columns subset
policy_df = policy_df[['COUNTRY_NAME', 'ISO3', 'POLICY_TYPE', 'POLICY_SUBTYPE',
       'START_DATE', 'AIR', 'TARGETS_AIR', 'LAND',
        'TARGETS_LAND', 'SEA', 'TARGETS_SEA',
       'CITIZEN', 'CITIZEN_LIST', 'HISTORY_BAN', 'HISTORY_BAN_LIST', 'REFUGEE',
       'REFUGEE_LIST', 'VISA_BAN', 'VISA_BAN_LIST',
       'CITIZEN_EXCEP', 'CITIZEN_EXCEP_LIST', 'COUNTRY_EXCEP',
       'COUNTRY_EXCEP_LIST', 'WORK_EXCEP']]
policy_df.columns
# Out:
# Index(['COUNTRY_NAME', 'ISO3', 'POLICY_TYPE', 'POLICY_SUBTYPE', 'START_DATE',
#        'AIR', 'TARGETS_AIR', 'LAND', 'TARGETS_LAND', 'SEA', 'TARGETS_SEA',
#        'CITIZEN', 'CITIZEN_LIST', 'HISTORY_BAN', 'HISTORY_BAN_LIST', 'REFUGEE',
#        'REFUGEE_LIST', 'VISA_BAN', 'VISA_BAN_LIST', 'CITIZEN_EXCEP',
#        'CITIZEN_EXCEP_LIST', 'COUNTRY_EXCEP', 'COUNTRY_EXCEP_LIST',
#        'WORK_EXCEP'],
#       dtype='object')

# %%
# renaming the columns
policy_df.columns = ['Country', 'Country_id', 'Policy_type', 'Policy_subtype', 'Start_date', 'Air_ban',
                             'Air_ban_info', 'Land_ban', 'Land_ban_info', 'Sea_ban', 
                              'Sea_ban_info','Citizen_ban', 'Citizen_ban_info', 
                              'Travel_history_ban', 'Travel_history_ban_info', 'Refugee_ban', 
                              'Refugee_ban_info', 'Visa_ban', 'Visa_ban_info', 
                              'Citizen_exceptions', 'Citizen_exceptions_info', 'Country_exceptions', 
                              'Country_exceptions_info', 'Work_exceptions_info']
policy_df.columns
# Out:
# Index(['Country', 'Country_id', 'Policy_type', 'Policy_subtype', 'Start_date',
#        'Air_ban', 'Air_ban_info', 'Land_ban', 'Land_ban_info', 'Sea_ban',
#        'Sea_ban_info', 'Citizen_ban', 'Citizen_ban_info', 'Travel_history_ban',
#        'Travel_history_ban_info', 'Refugee_ban', 'Refugee_ban_info',
#        'Visa_ban', 'Visa_ban_info', 'Citizen_exceptions',
#        'Citizen_exceptions_info', 'Country_exceptions',
#        'Country_exceptions_info', 'Work_exceptions_info'],
#       dtype='object')

# %%
# re-viewing the columns
policy_df.head()
# Out:
#                                   Country Country_id Policy_type  \
# 0                       Brunei Darussalam        BRN    COMPLETE
# 1                                 Morocco        MAR    COMPLETE
# 2  Korea, Democratic People's Republic of        PRK    COMPLETE
# 3                        Marshall Islands        MHL    COMPLETE
# 4        Lao People's Democratic Republic        LAO    COMPLETE
#
#    Policy_subtype Start_date  Air_ban Air_ban_info  Land_ban Land_ban_info  \
# 0  ESSENTIAL_ONLY   03_23_20        0          NaN         0           NaN
# 1  ESSENTIAL_ONLY   03_20_20        0          NaN         0           NaN
# 2  ESSENTIAL_ONLY   01_22_20        0          NaN         0           NaN
# 3  ESSENTIAL_ONLY   03_08_20        0          NaN         0           NaN
# 4  ESSENTIAL_ONLY   03_16_20        0          NaN         0           NaN
#
#    Sea_ban Sea_ban_info  Citizen_ban Citizen_ban_info  Travel_history_ban  \
# 0        0          NaN            0              NaN                   0
# 1        0          NaN            0              NaN                   0
# 2        0          NaN            0              NaN                   0
# 3        0          NaN            0              NaN                   0
# 4        0          NaN            0              NaN                   0
#
#   Travel_history_ban_info  Refugee_ban Refugee_ban_info  Visa_ban  \
# 0                     NaN            0              NaN         0
# 1                     NaN            0              NaN         0
# 2                     NaN            0              NaN         0
# 3                     NaN            0              NaN         0
# 4                     NaN            0              NaN         0
#
#   Visa_ban_info  Citizen_exceptions Citizen_exceptions_info  \
# 0           NaN                   0                     NaN
# 1           NaN                   0                     NaN
# 2           NaN                   0                     NaN
# 3           NaN                   0                     NaN
# 4           NaN                   0                     NaN
#
#    Country_exceptions Country_exceptions_info  Work_exceptions_info
# 0                   0                     NaN                     0
# 1                   0                     NaN                     0
# 2                   0                     NaN                     0
# 3                   0                     NaN                     0
# 4                   0                     NaN                     0

# %%
# checking which cols have null values
policy_df.isnull().sum()
# Out:
# Country                       0
# Country_id                    0
# Policy_type                   0
# Policy_subtype                0
# Start_date                    0
# Air_ban                       0
# Air_ban_info               1034
# Land_ban                      0
# Land_ban_info              1156
# Sea_ban                       0
# Sea_ban_info               1242
# Citizen_ban                   0
# Citizen_ban_info           1209
# Travel_history_ban            0
# Travel_history_ban_info    1154
# Refugee_ban                   0
# Refugee_ban_info           1270
# Visa_ban                      0
# Visa_ban_info              1236
# Citizen_exceptions            0
# Citizen_exceptions_info     904
# Country_exceptions            0
# Country_exceptions_info    1101
# Work_exceptions_info          0
# dtype: int64

# %%
# renaming NaNs
policy_df.fillna('no policy', inplace=True)
policy_df.head()
# Out:
#                                   Country Country_id Policy_type  \
# 0                       Brunei Darussalam        BRN    COMPLETE
# 1                                 Morocco        MAR    COMPLETE
# 2  Korea, Democratic People's Republic of        PRK    COMPLETE
# 3                        Marshall Islands        MHL    COMPLETE
# 4        Lao People's Democratic Republic        LAO    COMPLETE
#
#    Policy_subtype Start_date  Air_ban Air_ban_info  Land_ban Land_ban_info  \
# 0  ESSENTIAL_ONLY   03_23_20        0    no policy         0     no policy
# 1  ESSENTIAL_ONLY   03_20_20        0    no policy         0     no policy
# 2  ESSENTIAL_ONLY   01_22_20        0    no policy         0     no policy
# 3  ESSENTIAL_ONLY   03_08_20        0    no policy         0     no policy
# 4  ESSENTIAL_ONLY   03_16_20        0    no policy         0     no policy
#
#    Sea_ban Sea_ban_info  Citizen_ban Citizen_ban_info  Travel_history_ban  \
# 0        0    no policy            0        no policy                   0
# 1        0    no policy            0        no policy                   0
# 2        0    no policy            0        no policy                   0
# 3        0    no policy            0        no policy                   0
# 4        0    no policy            0        no policy                   0
#
#   Travel_history_ban_info  Refugee_ban Refugee_ban_info  Visa_ban  \
# 0               no policy            0        no policy         0
# 1               no policy            0        no policy         0
# 2               no policy            0        no policy         0
# 3               no policy            0        no policy         0
# 4               no policy            0        no policy         0
#
#   Visa_ban_info  Citizen_exceptions Citizen_exceptions_info  \
# 0     no policy                   0               no policy
# 1     no policy                   0               no policy
# 2     no policy                   0               no policy
# 3     no policy                   0               no policy
# 4     no policy                   0               no policy
#
#    Country_exceptions Country_exceptions_info  Work_exceptions_info
# 0                   0               no policy                     0
# 1                   0               no policy                     0
# 2                   0               no policy                     0
# 3                   0               no policy                     0
# 4                   0               no policy                     0

# %%
# finding length of dataframe
len(policy_df)
# Out:
# 1271

# %%
# finding number of countries in df
len(policy_df['Country_id'].unique())
# Out:
# 243

# %%
# sorting the country id alphabetically
sorted_policy_df = policy_df.sort_values('Country_id')
sorted_policy_df.head(20)
# Out:
#           Country Country_id Policy_type    Policy_subtype Start_date  \
# 194         Aruba        ABW    COMPLETE     CITIZEN_EXCEP   03_16_20
# 296         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY   07_10_20
# 84          Aruba        ABW    COMPLETE    ESSENTIAL_ONLY   03_26_20
# 295         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY   07_01_20
# 81          Aruba        ABW    COMPLETE    ESSENTIAL_ONLY   03_26_20
# 294         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY   06_15_20
# 210         Aruba        ABW    COMPLETE     CITIZEN_EXCEP   04_21_20
# 209         Aruba        ABW    COMPLETE     CITIZEN_EXCEP   03_17_20
# 217         Aruba        ABW    COMPLETE     CITIZEN_EXCEP   03_16_20
# 738   Afghanistan        AFG     PARTIAL    BORDER_CLOSURE   02_24_20
# 1017  Afghanistan        AFG     PARTIAL    BORDER_CLOSURE   03_24_20
# 1252       Angola        AGO     PARTIAL    BORDER_CLOSURE   10_19_20
# 1251       Angola        AGO     PARTIAL    BORDER_CLOSURE   10_01_20
# 732        Angola        AGO     PARTIAL       HISTORY_BAN   03_03_20
# 16         Angola        AGO    COMPLETE    ESSENTIAL_ONLY   03_20_20
# 251        Angola        AGO    COMPLETE     CITIZEN_EXCEP   05_26_20
# 733        Angola        AGO     PARTIAL       HISTORY_BAN   03_18_20
# 64       Anguilla        AIA    COMPLETE    ESSENTIAL_ONLY   03_20_20
# 299      Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY   07_12_20
# 1115     Anguilla        AIA     PARTIAL    BORDER_CLOSURE   03_24_20
#
#       Air_ban                                       Air_ban_info  Land_ban  \
# 194         0                                          no policy         0
# 296         0                                          no policy         0
# 84          0                                          no policy         0
# 295         0                                          no policy         0
# 81          0                                          no policy         0
# 294         0                                          no policy         0
# 210         0                                          no policy         0
# 209         0                                          no policy         0
# 217         0                                          no policy         0
# 738         0                                          no policy         1
# 1017        1  all commercial flights suspended except for so...         0
# 1252        1  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 1251        1  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 732         0                                          no policy         0
# 16          0                                          no policy         0
# 251         0                                          no policy         0
# 733         0                                          no policy         0
# 64          0                                          no policy         0
# 299         0                                          no policy         0
# 1115        1                                          no policy         0
#
#      Land_ban_info  Sea_ban  \
# 194      no policy        0
# 296      no policy        0
# 84       no policy        0
# 295      no policy        0
# 81       no policy        0
# 294      no policy        0
# 210      no policy        0
# 209      no policy        0
# 217      no policy        0
# 738           Iran        0
# 1017     no policy        0
# 1252     no policy        1
# 1251     no policy        1
# 732      no policy        0
# 16       no policy        0
# 251      no policy        0
# 733      no policy        0
# 64       no policy        0
# 299      no policy        0
# 1115     no policy        1
#
#                                            Sea_ban_info  Citizen_ban  \
# 194                                           no policy            0
# 296                                           no policy            0
# 84                                            no policy            0
# 295                                           no policy            0
# 81                                            no policy            0
# 294                                           no policy            0
# 210                                           no policy            0
# 209                                           no policy            0
# 217                                           no policy            0
# 738                                           no policy            0
# 1017                                          no policy            0
# 1252                                          no policy            0
# 1251                                          no policy            0
# 732                                           no policy            0
# 16                                            no policy            0
# 251                                           no policy            0
# 733                                           no policy            0
# 64                                            no policy            0
# 299                                           no policy            0
# 1115  Blowing Point Ferry Terminal closed until furt...            0
#
#      Citizen_ban_info  Travel_history_ban  \
# 194         no policy                   0
# 296         no policy                   0
# 84          no policy                   0
# 295         no policy                   0
# 81          no policy                   0
# 294         no policy                   0
# 210         no policy                   0
# 209         no policy                   0
# 217         no policy                   0
# 738         no policy                   0
# 1017        no policy                   0
# 1252        no policy                   0
# 1251        no policy                   0
# 732         no policy                   1
# 16          no policy                   0
# 251         no policy                   0
# 733         no policy                   1
# 64          no policy                   0
# 299         no policy                   0
# 1115        no policy                   0
#
#                                 Travel_history_ban_info  Refugee_ban  \
# 194                                           no policy            0
# 296                                           no policy            0
# 84                                            no policy            0
# 295                                           no policy            0
# 81                                            no policy            0
# 294                                           no policy            0
# 210                                           no policy            0
# 209                                           no policy            0
# 217                                           no policy            0
# 738                                           no policy            0
# 1017                                          no policy            0
# 1252                                          no policy            0
# 1251                                          no policy            0
# 732                     China, South Korea, Italy, Iran            0
# 16                                            no policy            0
# 251                                           no policy            0
# 733   China, South Korea, Italy, Iran, Portugal, Spa...            0
# 64                                            no policy            0
# 299                                           no policy            0
# 1115                                          no policy            0
#
#      Refugee_ban_info  Visa_ban Visa_ban_info  Citizen_exceptions  \
# 194         no policy         0     no policy                   1
# 296         no policy         0     no policy                   1
# 84          no policy         0     no policy                   0
# 295         no policy         0     no policy                   1
# 81          no policy         0     no policy                   0
# 294         no policy         0     no policy                   1
# 210         no policy         0     no policy                   1
# 209         no policy         0     no policy                   1
# 217         no policy         0     no policy                   1
# 738         no policy         0     no policy                   0
# 1017        no policy         0     no policy                   0
# 1252        no policy         0     no policy                   0
# 1251        no policy         0     no policy                   0
# 732         no policy         0     no policy                   0
# 16          no policy         0     no policy                   0
# 251         no policy         0     no policy                   1
# 733         no policy         0     no policy                   0
# 64          no policy         0     no policy                   0
# 299         no policy         0     no policy                   1
# 1115        no policy         0     no policy                   0
#
#                                 Citizen_exceptions_info  Country_exceptions  \
# 194                       citizens, permanent residents                   0
# 296   residents with prior authorization, non-reside...                   1
# 84                                            no policy                   0
# 295   residents with prior authorization, non-reside...                   1
# 81                                            no policy                   0
# 294   residents with prior authorization, non-reside...                   1
# 210   residents of Aruba with prior authorization, n...                   0
# 209                                           residents                   0
# 217   citizens, permanent residents, family members ...                   0
# 738                                           no policy                   0
# 1017                                          no policy                   0
# 1252                                          no policy                   0
# 1251                                          no policy                   0
# 732                                           no policy                   0
# 16                                            no policy                   0
# 251                        nationals, foreign residents                   0
# 733                                           no policy                   0
# 64                                            no policy                   0
# 299                                 citizens, residents                   1
# 1115                                          no policy                   0
#
#                                 Country_exceptions_info  Work_exceptions_info
# 194                                           no policy                     0
# 296   Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 84                                            no policy                     0
# 295   Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 81                                            no policy                     0
# 294            Curacao, Bonaire, St. Eustatius and Saba                     0
# 210                                           no policy                     0
# 209                                           no policy                     0
# 217                                           no policy                     0
# 738                                           no policy                     0
# 1017                                          no policy                     0
# 1252                                          no policy                     0
# 1251                                          no policy                     0
# 732                                           no policy                     0
# 16                                            no policy                     0
# 251                                           no policy                     0
# 733                                           no policy                     0
# 64                                            no policy                     0
# 299   Aruba, Bonaire, St Eustatius and Saba, Belize,...                     0
# 1115                                          no policy                     0

# %%
# finding dtype for Start Date col
sorted_policy_df['Start_date'].dtype
# Out:
# dtype('O')

# %%
# formatting dates for use in datetime
# replacing nons and 0s with fake date 
dates_list = [x.replace('_', '-') for x in sorted_policy_df['Start_date']]
dates_list_start = ['01-01-01' if x == 'NONE' or x == '0' else x for x in dates_list]
# educated guess as to end date of errant date shown in below cell
dates_list_edited = ['04-21-20' if x == '04-31-20' else x for x in dates_list_start]

# %%
# impossible date
sorted_policy_df[sorted_policy_df['Start_date'] == '04-31-20']
# Out:
# Empty DataFrame
# Columns: [Country, Country_id, Policy_type, Policy_subtype, Start_date, Air_ban, Air_ban_info, Land_ban, Land_ban_info, Sea_ban, Sea_ban_info, Citizen_ban, Citizen_ban_info, Travel_history_ban, Travel_history_ban_info, Refugee_ban, Refugee_ban_info, Visa_ban, Visa_ban_info, Citizen_exceptions, Citizen_exceptions_info, Country_exceptions, Country_exceptions_info, Work_exceptions_info]
# Index: []

# %%
# replacing Start Date col w/ edited dates list
sorted_policy_df['Start_date'] = dates_list_edited
sorted_policy_df.head()
# Out:
#     Country Country_id Policy_type    Policy_subtype Start_date  Air_ban  \
# 194   Aruba        ABW    COMPLETE     CITIZEN_EXCEP   03-16-20        0
# 296   Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY   07-10-20        0
# 84    Aruba        ABW    COMPLETE    ESSENTIAL_ONLY   03-26-20        0
# 295   Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY   07-01-20        0
# 81    Aruba        ABW    COMPLETE    ESSENTIAL_ONLY   03-26-20        0
#
#     Air_ban_info  Land_ban Land_ban_info  Sea_ban Sea_ban_info  Citizen_ban  \
# 194    no policy         0     no policy        0    no policy            0
# 296    no policy         0     no policy        0    no policy            0
# 84     no policy         0     no policy        0    no policy            0
# 295    no policy         0     no policy        0    no policy            0
# 81     no policy         0     no policy        0    no policy            0
#
#     Citizen_ban_info  Travel_history_ban Travel_history_ban_info  Refugee_ban  \
# 194        no policy                   0               no policy            0
# 296        no policy                   0               no policy            0
# 84         no policy                   0               no policy            0
# 295        no policy                   0               no policy            0
# 81         no policy                   0               no policy            0
#
#     Refugee_ban_info  Visa_ban Visa_ban_info  Citizen_exceptions  \
# 194        no policy         0     no policy                   1
# 296        no policy         0     no policy                   1
# 84         no policy         0     no policy                   0
# 295        no policy         0     no policy                   1
# 81         no policy         0     no policy                   0
#
#                                Citizen_exceptions_info  Country_exceptions  \
# 194                      citizens, permanent residents                   0
# 296  residents with prior authorization, non-reside...                   1
# 84                                           no policy                   0
# 295  residents with prior authorization, non-reside...                   1
# 81                                           no policy                   0
#
#                                Country_exceptions_info  Work_exceptions_info
# 194                                          no policy                     0
# 296  Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 84                                           no policy                     0
# 295  Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 81                                           no policy                     0

# %%
# converting Start Date col to dtype datetime
sorted_policy_df['Start_date'] = pd.to_datetime(sorted_policy_df['Start_date'])

# %%
# checking dtype
sorted_policy_df['Start_date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# sorting by country id then start date
double_sorted_policy_df = sorted_policy_df.sort_values(['Country_id','Start_date'])
double_sorted_policy_df.head(20)
# Out:
#           Country Country_id Policy_type    Policy_subtype Start_date  \
# 194         Aruba        ABW    COMPLETE     CITIZEN_EXCEP 2020-03-16
# 217         Aruba        ABW    COMPLETE     CITIZEN_EXCEP 2020-03-16
# 209         Aruba        ABW    COMPLETE     CITIZEN_EXCEP 2020-03-17
# 84          Aruba        ABW    COMPLETE    ESSENTIAL_ONLY 2020-03-26
# 81          Aruba        ABW    COMPLETE    ESSENTIAL_ONLY 2020-03-26
# 210         Aruba        ABW    COMPLETE     CITIZEN_EXCEP 2020-04-21
# 294         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY 2020-06-15
# 295         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY 2020-07-01
# 296         Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY 2020-07-10
# 738   Afghanistan        AFG     PARTIAL    BORDER_CLOSURE 2020-02-24
# 1017  Afghanistan        AFG     PARTIAL    BORDER_CLOSURE 2020-03-24
# 732        Angola        AGO     PARTIAL       HISTORY_BAN 2020-03-03
# 733        Angola        AGO     PARTIAL       HISTORY_BAN 2020-03-18
# 16         Angola        AGO    COMPLETE    ESSENTIAL_ONLY 2020-03-20
# 251        Angola        AGO    COMPLETE     CITIZEN_EXCEP 2020-05-26
# 1251       Angola        AGO     PARTIAL    BORDER_CLOSURE 2020-10-01
# 1252       Angola        AGO     PARTIAL    BORDER_CLOSURE 2020-10-19
# 64       Anguilla        AIA    COMPLETE    ESSENTIAL_ONLY 2020-03-20
# 1115     Anguilla        AIA     PARTIAL    BORDER_CLOSURE 2020-03-24
# 298      Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY 2020-04-04
#
#       Air_ban                                       Air_ban_info  Land_ban  \
# 194         0                                          no policy         0
# 217         0                                          no policy         0
# 209         0                                          no policy         0
# 84          0                                          no policy         0
# 81          0                                          no policy         0
# 210         0                                          no policy         0
# 294         0                                          no policy         0
# 295         0                                          no policy         0
# 296         0                                          no policy         0
# 738         0                                          no policy         1
# 1017        1  all commercial flights suspended except for so...         0
# 732         0                                          no policy         0
# 733         0                                          no policy         0
# 16          0                                          no policy         0
# 251         0                                          no policy         0
# 1251        1  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 1252        1  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 64          0                                          no policy         0
# 1115        1                                          no policy         0
# 298         0                                          no policy         0
#
#      Land_ban_info  Sea_ban  \
# 194      no policy        0
# 217      no policy        0
# 209      no policy        0
# 84       no policy        0
# 81       no policy        0
# 210      no policy        0
# 294      no policy        0
# 295      no policy        0
# 296      no policy        0
# 738           Iran        0
# 1017     no policy        0
# 732      no policy        0
# 733      no policy        0
# 16       no policy        0
# 251      no policy        0
# 1251     no policy        1
# 1252     no policy        1
# 64       no policy        0
# 1115     no policy        1
# 298      no policy        0
#
#                                            Sea_ban_info  Citizen_ban  \
# 194                                           no policy            0
# 217                                           no policy            0
# 209                                           no policy            0
# 84                                            no policy            0
# 81                                            no policy            0
# 210                                           no policy            0
# 294                                           no policy            0
# 295                                           no policy            0
# 296                                           no policy            0
# 738                                           no policy            0
# 1017                                          no policy            0
# 732                                           no policy            0
# 733                                           no policy            0
# 16                                            no policy            0
# 251                                           no policy            0
# 1251                                          no policy            0
# 1252                                          no policy            0
# 64                                            no policy            0
# 1115  Blowing Point Ferry Terminal closed until furt...            0
# 298                                           no policy            0
#
#      Citizen_ban_info  Travel_history_ban  \
# 194         no policy                   0
# 217         no policy                   0
# 209         no policy                   0
# 84          no policy                   0
# 81          no policy                   0
# 210         no policy                   0
# 294         no policy                   0
# 295         no policy                   0
# 296         no policy                   0
# 738         no policy                   0
# 1017        no policy                   0
# 732         no policy                   1
# 733         no policy                   1
# 16          no policy                   0
# 251         no policy                   0
# 1251        no policy                   0
# 1252        no policy                   0
# 64          no policy                   0
# 1115        no policy                   0
# 298         no policy                   0
#
#                                 Travel_history_ban_info  Refugee_ban  \
# 194                                           no policy            0
# 217                                           no policy            0
# 209                                           no policy            0
# 84                                            no policy            0
# 81                                            no policy            0
# 210                                           no policy            0
# 294                                           no policy            0
# 295                                           no policy            0
# 296                                           no policy            0
# 738                                           no policy            0
# 1017                                          no policy            0
# 732                     China, South Korea, Italy, Iran            0
# 733   China, South Korea, Italy, Iran, Portugal, Spa...            0
# 16                                            no policy            0
# 251                                           no policy            0
# 1251                                          no policy            0
# 1252                                          no policy            0
# 64                                            no policy            0
# 1115                                          no policy            0
# 298                                           no policy            0
#
#      Refugee_ban_info  Visa_ban Visa_ban_info  Citizen_exceptions  \
# 194         no policy         0     no policy                   1
# 217         no policy         0     no policy                   1
# 209         no policy         0     no policy                   1
# 84          no policy         0     no policy                   0
# 81          no policy         0     no policy                   0
# 210         no policy         0     no policy                   1
# 294         no policy         0     no policy                   1
# 295         no policy         0     no policy                   1
# 296         no policy         0     no policy                   1
# 738         no policy         0     no policy                   0
# 1017        no policy         0     no policy                   0
# 732         no policy         0     no policy                   0
# 733         no policy         0     no policy                   0
# 16          no policy         0     no policy                   0
# 251         no policy         0     no policy                   1
# 1251        no policy         0     no policy                   0
# 1252        no policy         0     no policy                   0
# 64          no policy         0     no policy                   0
# 1115        no policy         0     no policy                   0
# 298         no policy         0     no policy                   1
#
#                                 Citizen_exceptions_info  Country_exceptions  \
# 194                       citizens, permanent residents                   0
# 217   citizens, permanent residents, family members ...                   0
# 209                                           residents                   0
# 84                                            no policy                   0
# 81                                            no policy                   0
# 210   residents of Aruba with prior authorization, n...                   0
# 294   residents with prior authorization, non-reside...                   1
# 295   residents with prior authorization, non-reside...                   1
# 296   residents with prior authorization, non-reside...                   1
# 738                                           no policy                   0
# 1017                                          no policy                   0
# 732                                           no policy                   0
# 733                                           no policy                   0
# 16                                            no policy                   0
# 251                        nationals, foreign residents                   0
# 1251                                          no policy                   0
# 1252                                          no policy                   0
# 64                                            no policy                   0
# 1115                                          no policy                   0
# 298                                 citizens, residents                   1
#
#                                 Country_exceptions_info  Work_exceptions_info
# 194                                           no policy                     0
# 217                                           no policy                     0
# 209                                           no policy                     0
# 84                                            no policy                     0
# 81                                            no policy                     0
# 210                                           no policy                     0
# 294            Curacao, Bonaire, St. Eustatius and Saba                     0
# 295   Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 296   Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 738                                           no policy                     0
# 1017                                          no policy                     0
# 732                                           no policy                     0
# 733                                           no policy                     0
# 16                                            no policy                     0
# 251                                           no policy                     0
# 1251                                          no policy                     0
# 1252                                          no policy                     0
# 64                                            no policy                     0
# 1115                                          no policy                     0
# 298                                       United States                     0

# %%
# keeping only the rows with the most recent date for each country
last_date_df = double_sorted_policy_df.drop_duplicates(subset='Country_id', keep='last')
last_date_df.head(20)
# Out:
#                                Country Country_id          Policy_type  \
# 296                              Aruba        ABW             COMPLETE
# 1017                       Afghanistan        AFG              PARTIAL
# 1252                            Angola        AGO              PARTIAL
# 299                           Anguilla        AIA             COMPLETE
# 423                      Åland Islands        ALA             COMPLETE
# 884                            Albania        ALB              PARTIAL
# 1265                           Andorra        AND  NOPOLICYIMPLEMENTED
# 511               United Arab Emirates        ARE              PARTIAL
# 1095                         Argentina        ARG              PARTIAL
# 888                            Armenia        ARM              PARTIAL
# 244                     American Samoa        ASM             COMPLETE
# 1264                        Antarctica        ATA  NOPOLICYIMPLEMENTED
# 300                Antigua and Barbuda        ATG             COMPLETE
# 272                          Australia        AUS             COMPLETE
# 969                            Austria        AUT              PARTIAL
# 1070                        Azerbaijan        AZE              PARTIAL
# 1197                           Burundi        BDI              PARTIAL
# 971                            Belgium        BEL              PARTIAL
# 972                              Benin        BEN              PARTIAL
# 433   Bonaire, Sint Eustatius and Saba        BES             COMPLETE
#
#         Policy_subtype Start_date  Air_ban  \
# 296   SPECIFIC_COUNTRY 2020-07-10        0
# 1017    BORDER_CLOSURE 2020-03-24        1
# 1252    BORDER_CLOSURE 2020-10-19        1
# 299   SPECIFIC_COUNTRY 2020-07-12        0
# 423         WORK_EXCEP 2020-11-19        0
# 884     BORDER_CLOSURE 2020-03-24        0
# 1265              NONE 2001-01-01        0
# 511           VISA_BAN 2020-04-03        0
# 1095    BORDER_CLOSURE 2020-11-01        1
# 888     BORDER_CLOSURE 2020-03-24        1
# 244      CITIZEN_EXCEP 2020-12-01        0
# 1264              NONE 2001-01-01        0
# 300   SPECIFIC_COUNTRY 2020-04-23        0
# 272   SPECIFIC_COUNTRY 2020-10-16        0
# 969     BORDER_CLOSURE 2020-03-19        0
# 1070    BORDER_CLOSURE 2020-08-29        1
# 1197    BORDER_CLOSURE 2021-01-11        0
# 971     BORDER_CLOSURE 2020-04-15        1
# 972     BORDER_CLOSURE 2020-04-17        0
# 433         WORK_EXCEP 2020-11-20        0
#
#                                            Air_ban_info  Land_ban  \
# 296                                           no policy         0
# 1017  all commercial flights suspended except for so...         0
# 1252  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 299                                           no policy         0
# 423                                           no policy         0
# 884                                           no policy         0
# 1265                                          no policy         0
# 511                                           no policy         0
# 1095                       Only citizens allowed to fly         0
# 888   Australia, Canada, China, EU member states, Ge...         0
# 244                                           no policy         0
# 1264                                          no policy         0
# 300                                           no policy         0
# 272                                           no policy         0
# 969                                           no policy         1
# 1070                                          no policy         0
# 1197                                          no policy         1
# 971   All countries except Austria, Belgium, Bulgari...         0
# 972                                           no policy         1
# 433                                           no policy         0
#
#           Land_ban_info  Sea_ban  \
# 296           no policy        0
# 1017          no policy        0
# 1252          no policy        1
# 299           no policy        0
# 423           no policy        0
# 884           no policy        1
# 1265          no policy        0
# 511           no policy        0
# 1095          no policy        0
# 888           no policy        0
# 244           no policy        0
# 1264          no policy        0
# 300           no policy        0
# 272           no policy        0
# 969   Hungary, Slovenia        0
# 1070          no policy        0
# 1197          no policy        1
# 971           no policy        0
# 972                Togo        0
# 433           no policy        0
#
#                                            Sea_ban_info  Citizen_ban  \
# 296                                           no policy            0
# 1017                                          no policy            0
# 1252                                          no policy            0
# 299                                           no policy            0
# 423                                           no policy            0
# 884   All ferries to/from Italy & other red areas ar...            0
# 1265                                          no policy            0
# 511                                           no policy            0
# 1095                                          no policy            0
# 888                                           no policy            0
# 244                                           no policy            0
# 1264                                          no policy            0
# 300                                           no policy            0
# 272                                           no policy            0
# 969                                           no policy            0
# 1070                                          no policy            0
# 1197                                          no policy            0
# 971                                           no policy            0
# 972                                           no policy            0
# 433                                           no policy            0
#
#      Citizen_ban_info  Travel_history_ban Travel_history_ban_info  \
# 296         no policy                   0               no policy
# 1017        no policy                   0               no policy
# 1252        no policy                   0               no policy
# 299         no policy                   0               no policy
# 423         no policy                   0               no policy
# 884         no policy                   0               no policy
# 1265        no policy                   0               no policy
# 511         no policy                   0               no policy
# 1095        no policy                   0               no policy
# 888         no policy                   0               no policy
# 244         no policy                   0               no policy
# 1264        no policy                   0               no policy
# 300         no policy                   0               no policy
# 272         no policy                   0               no policy
# 969         no policy                   0               no policy
# 1070        no policy                   0               no policy
# 1197        no policy                   0               no policy
# 971         no policy                   0               no policy
# 972         no policy                   0               no policy
# 433         no policy                   0               no policy
#
#       Refugee_ban Refugee_ban_info  Visa_ban  \
# 296             0        no policy         0
# 1017            0        no policy         0
# 1252            0        no policy         0
# 299             0        no policy         0
# 423             0        no policy         0
# 884             0        no policy         0
# 1265            0        no policy         0
# 511             0        no policy         1
# 1095            0        no policy         0
# 888             0        no policy         0
# 244             0        no policy         0
# 1264            0        no policy         0
# 300             0        no policy         0
# 272             0        no policy         0
# 969             0        no policy         0
# 1070            0        no policy         0
# 1197            0        no policy         0
# 971             0        no policy         0
# 972             0        no policy         0
# 433             0        no policy         0
#
#                                          Visa_ban_info  Citizen_exceptions  \
# 296                                          no policy                   1
# 1017                                         no policy                   0
# 1252                                         no policy                   0
# 299                                          no policy                   1
# 423                                          no policy                   1
# 884                                          no policy                   0
# 1265                                         no policy                   0
# 511   New visa seekers and existing valid visa holders                   0
# 1095                                         no policy                   0
# 888                                          no policy                   0
# 244                                          no policy                   1
# 1264                                         no policy                   0
# 300                                          no policy                   0
# 272                                          no policy                   1
# 969                                          no policy                   0
# 1070                                         no policy                   0
# 1197                                         no policy                   0
# 971                                          no policy                   0
# 972                                          no policy                   0
# 433                                          no policy                   1
#
#                                 Citizen_exceptions_info  Country_exceptions  \
# 296   residents with prior authorization, non-reside...                   1
# 1017                                          no policy                   0
# 1252                                          no policy                   0
# 299                                 citizens, residents                   1
# 423   nationals of Finland, family members of nation...                   1
# 884                                           no policy                   0
# 1265                                          no policy                   0
# 511                                           no policy                   0
# 1095                                          no policy                   0
# 888                                           no policy                   0
# 244                                            citizens                   0
# 1264                                          no policy                   0
# 300                                           no policy                   1
# 272   Australian Citizens, permanent residents in Au...                   1
# 969                                           no policy                   0
# 1070                                          no policy                   0
# 1197                                          no policy                   0
# 971                                           no policy                   0
# 972                                           no policy                   0
# 433                       citizens, permanent residents                   1
#
#                                 Country_exceptions_info  Work_exceptions_info
# 296   Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 1017                                          no policy                     0
# 1252                                          no policy                     0
# 299   Aruba, Bonaire, St Eustatius and Saba, Belize,...                     0
# 423   Vactican City, Australia, South Korea, Japan, ...                     1
# 884                                           no policy                     0
# 1265                                          no policy                     0
# 511                                           no policy                     0
# 1095                                          no policy                     0
# 888                                           no policy                     0
# 244                                           no policy                     0
# 1264                                          no policy                     0
# 300                                  Dominican Republic                     0
# 272   New Zealand (quarantine free travel if people ...                     0
# 969                                           no policy                     0
# 1070                                          no policy                     0
# 1197                                          no policy                     0
# 971                                           no policy                     0
# 972                                           no policy                     0
# 433   Saba, Antiga, Anguilla, Montserrat, Saint Vinc...                     1

# %%
# len of df
len(last_date_df)
# Out:
# 243

# %%
# showing cols of df
last_date_df.columns
# Out:
# Index(['Country', 'Country_id', 'Policy_type', 'Policy_subtype', 'Start_date',
#        'Air_ban', 'Air_ban_info', 'Land_ban', 'Land_ban_info', 'Sea_ban',
#        'Sea_ban_info', 'Citizen_ban', 'Citizen_ban_info', 'Travel_history_ban',
#        'Travel_history_ban_info', 'Refugee_ban', 'Refugee_ban_info',
#        'Visa_ban', 'Visa_ban_info', 'Citizen_exceptions',
#        'Citizen_exceptions_info', 'Country_exceptions',
#        'Country_exceptions_info', 'Work_exceptions_info'],
#       dtype='object')

# %%
# separating out only rows where a complete ban was in effect, saving only cols that apply
full_closures_df = last_date_df[last_date_df['Policy_type'] == 'COMPLETE'][['Country', 'Country_id', 'Policy_type', 'Policy_subtype', 'Start_date', 'Citizen_exceptions',
       'Citizen_exceptions_info', 'Country_exceptions',
       'Country_exceptions_info', 'Work_exceptions_info']]
full_closures_df.reset_index(inplace=True, drop=True)
full_closures_df.head(10)
# Out:
#                             Country Country_id Policy_type    Policy_subtype  \
# 0                             Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY
# 1                          Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY
# 2                     Åland Islands        ALA    COMPLETE        WORK_EXCEP
# 3                    American Samoa        ASM    COMPLETE     CITIZEN_EXCEP
# 4               Antigua and Barbuda        ATG    COMPLETE  SPECIFIC_COUNTRY
# 5                         Australia        AUS    COMPLETE  SPECIFIC_COUNTRY
# 6  Bonaire, Sint Eustatius and Saba        BES    COMPLETE        WORK_EXCEP
# 7                          Bulgaria        BGR    COMPLETE  SPECIFIC_COUNTRY
# 8                           Bahrain        BHR    COMPLETE     CITIZEN_EXCEP
# 9                           Bahamas        BHS    COMPLETE    ESSENTIAL_ONLY
#
#   Start_date  Citizen_exceptions  \
# 0 2020-07-10                   1
# 1 2020-07-12                   1
# 2 2020-11-19                   1
# 3 2020-12-01                   1
# 4 2020-04-23                   0
# 5 2020-10-16                   1
# 6 2020-11-20                   1
# 7 2020-07-16                   1
# 8 2020-06-04                   1
# 9 2020-03-24                   0
#
#                              Citizen_exceptions_info  Country_exceptions  \
# 0  residents with prior authorization, non-reside...                   1
# 1                                citizens, residents                   1
# 2  nationals of Finland, family members of nation...                   1
# 3                                           citizens                   0
# 4                                          no policy                   1
# 5  Australian Citizens, permanent residents in Au...                   1
# 6                      citizens, permanent residents                   1
# 7                                citizens, residents                   1
# 8                      citizens, permanent residents                   0
# 9                                          no policy                   0
#
#                              Country_exceptions_info  Work_exceptions_info
# 0  Antiga and Barbuda, The Bahamas, Barbados, Cub...                     0
# 1  Aruba, Bonaire, St Eustatius and Saba, Belize,...                     0
# 2  Vactican City, Australia, South Korea, Japan, ...                     1
# 3                                          no policy                     0
# 4                                 Dominican Republic                     0
# 5  New Zealand (quarantine free travel if people ...                     0
# 6  Saba, Antiga, Anguilla, Montserrat, Saint Vinc...                     1
# 7  The Republic of Austria, The Kingdom of Nether...                     0
# 8                                          no policy                     0
# 9                                          no policy                     0

# %%
# separating out only rows where a partial ban was in effect, saving only cols that apply
partial_closures_df = last_date_df[last_date_df['Policy_type'] == 'PARTIAL'][['Country', 'Country_id', 
       'Policy_type', 'Policy_subtype', 'Start_date', 'Air_ban', 'Air_ban_info', 'Land_ban', 'Land_ban_info', 
       'Sea_ban','Sea_ban_info', 'Citizen_ban', 'Citizen_ban_info', 'Travel_history_ban', 'Travel_history_ban_info',
       'Refugee_ban', 'Refugee_ban_info', 'Visa_ban', 'Visa_ban_info']]
partial_closures_df.reset_index(inplace=True, drop=True)
partial_closures_df.head(10)
# Out:
#                 Country Country_id Policy_type  Policy_subtype Start_date  \
# 0           Afghanistan        AFG     PARTIAL  BORDER_CLOSURE 2020-03-24
# 1                Angola        AGO     PARTIAL  BORDER_CLOSURE 2020-10-19
# 2               Albania        ALB     PARTIAL  BORDER_CLOSURE 2020-03-24
# 3  United Arab Emirates        ARE     PARTIAL        VISA_BAN 2020-04-03
# 4             Argentina        ARG     PARTIAL  BORDER_CLOSURE 2020-11-01
# 5               Armenia        ARM     PARTIAL  BORDER_CLOSURE 2020-03-24
# 6               Austria        AUT     PARTIAL  BORDER_CLOSURE 2020-03-19
# 7            Azerbaijan        AZE     PARTIAL  BORDER_CLOSURE 2020-08-29
# 8               Burundi        BDI     PARTIAL  BORDER_CLOSURE 2021-01-11
# 9               Belgium        BEL     PARTIAL  BORDER_CLOSURE 2020-04-15
#
#    Air_ban                                       Air_ban_info  Land_ban  \
# 0        1  all commercial flights suspended except for so...         0
# 1        1  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 2        0                                          no policy         0
# 3        0                                          no policy         0
# 4        1                       Only citizens allowed to fly         0
# 5        1  Australia, Canada, China, EU member states, Ge...         0
# 6        0                                          no policy         1
# 7        1                                          no policy         0
# 8        0                                          no policy         1
# 9        1  All countries except Austria, Belgium, Bulgari...         0
#
#        Land_ban_info  Sea_ban  \
# 0          no policy        0
# 1          no policy        1
# 2          no policy        1
# 3          no policy        0
# 4          no policy        0
# 5          no policy        0
# 6  Hungary, Slovenia        0
# 7          no policy        0
# 8          no policy        1
# 9          no policy        0
#
#                                         Sea_ban_info  Citizen_ban  \
# 0                                          no policy            0
# 1                                          no policy            0
# 2  All ferries to/from Italy & other red areas ar...            0
# 3                                          no policy            0
# 4                                          no policy            0
# 5                                          no policy            0
# 6                                          no policy            0
# 7                                          no policy            0
# 8                                          no policy            0
# 9                                          no policy            0
#
#   Citizen_ban_info  Travel_history_ban Travel_history_ban_info  Refugee_ban  \
# 0        no policy                   0               no policy            0
# 1        no policy                   0               no policy            0
# 2        no policy                   0               no policy            0
# 3        no policy                   0               no policy            0
# 4        no policy                   0               no policy            0
# 5        no policy                   0               no policy            0
# 6        no policy                   0               no policy            0
# 7        no policy                   0               no policy            0
# 8        no policy                   0               no policy            0
# 9        no policy                   0               no policy            0
#
#   Refugee_ban_info  Visa_ban                                     Visa_ban_info
# 0        no policy         0                                         no policy
# 1        no policy         0                                         no policy
# 2        no policy         0                                         no policy
# 3        no policy         1  New visa seekers and existing valid visa holders
# 4        no policy         0                                         no policy
# 5        no policy         0                                         no policy
# 6        no policy         0                                         no policy
# 7        no policy         0                                         no policy
# 8        no policy         0                                         no policy
# 9        no policy         0                                         no policy

# %%
# separating out only rows where no ban was in effect, saving only cols that apply
no_closures_df = last_date_df[last_date_df['Policy_type'] == 'NOPOLICYIMPLEMENTED'][['Country', 'Country_id', 'Policy_type', 'Policy_subtype']]
no_closures_df.reset_index(inplace=True, drop=True)
no_closures_df.head(10)
# Out:
#        Country Country_id          Policy_type Policy_subtype
# 0      Andorra        AND  NOPOLICYIMPLEMENTED           NONE
# 1   Antarctica        ATA  NOPOLICYIMPLEMENTED           NONE
# 2     Guernsey        GGY  NOPOLICYIMPLEMENTED           NONE
# 3         Guam        GUM  NOPOLICYIMPLEMENTED           NONE
# 4       Jersey        JEY  NOPOLICYIMPLEMENTED           NONE
# 5    Nicaragua        NIC  NOPOLICYIMPLEMENTED           NONE
# 6  Puerto Rico        PRI  NOPOLICYIMPLEMENTED           NONE
# 7   San Marino        SMR  NOPOLICYIMPLEMENTED           NONE

# %%
# checking lengths of the 3 dfs
len(full_closures_df), len(partial_closures_df), len(no_closures_df)
# Out:
# (108, 127, 8)

# %%
# reading in csvs
vaccinations_df = pd.read_csv('Clean/vaccinations_cleaned.csv')
travel_df = pd.read_csv('Clean/travel_restrictions_clean.csv')

# %%
# doing first merge w/ each of the 3 closure dfs, w/ the travel restrictions df
full_closures_merged = full_closures_df.merge(travel_df, how='inner', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
full_closures_merged.head()
# Out:
#                Country Country_id Policy_type    Policy_subtype Start_date  \
# 0                Aruba        ABW    COMPLETE  SPECIFIC_COUNTRY 2020-07-10
# 1             Anguilla        AIA    COMPLETE  SPECIFIC_COUNTRY 2020-07-12
# 2        Åland Islands        ALA    COMPLETE        WORK_EXCEP 2020-11-19
# 3       American Samoa        ASM    COMPLETE     CITIZEN_EXCEP 2020-12-01
# 4  Antigua and Barbuda        ATG    COMPLETE  SPECIFIC_COUNTRY 2020-04-23
#
#    Citizen_exceptions                            Citizen_exceptions_info  \
# 0                   1  residents with prior authorization, non-reside...
# 1                   1                                citizens, residents
# 2                   1  nationals of Finland, family members of nation...
# 3                   1                                           citizens
# 4                   0                                          no policy
#
#    Country_exceptions                            Country_exceptions_info  \
# 0                   1  Antiga and Barbuda, The Bahamas, Barbados, Cub...
# 1                   1  Aruba, Bonaire, St Eustatius and Saba, Belize,...
# 2                   1  Vactican City, Australia, South Korea, Japan, ...
# 3                   0                                          no policy
# 4                   1                                 Dominican Republic
#
#    Work_exceptions_info                                    Quarantine_type
# 0                     0  Self-isolation at own accommodation- subject t...
# 1                     0  Quarantine at government designated site or Go...
# 2                     1                                            Unknown
# 3                     0  Quarantine Requirement outside territory. <br>...
# 4                     0  Quarantine requirement at government designate...

# %%
# doing first merge w/ each of the 3 closure dfs, w/ the travel restrictions df
partial_closures_merged = partial_closures_df.merge(travel_df, how='inner', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
partial_closures_merged.head()
# Out:
#                 Country Country_id Policy_type  Policy_subtype Start_date  \
# 0           Afghanistan        AFG     PARTIAL  BORDER_CLOSURE 2020-03-24
# 1                Angola        AGO     PARTIAL  BORDER_CLOSURE 2020-10-19
# 2               Albania        ALB     PARTIAL  BORDER_CLOSURE 2020-03-24
# 3  United Arab Emirates        ARE     PARTIAL        VISA_BAN 2020-04-03
# 4             Argentina        ARG     PARTIAL  BORDER_CLOSURE 2020-11-01
#
#    Air_ban                                       Air_ban_info  Land_ban  \
# 0        1  all commercial flights suspended except for so...         0
# 1        1  Afghanistan, Aland Islands, Albania, Algeria, ...         1
# 2        0                                          no policy         0
# 3        0                                          no policy         0
# 4        1                       Only citizens allowed to fly         0
#
#   Land_ban_info  Sea_ban                                       Sea_ban_info  \
# 0     no policy        0                                          no policy
# 1     no policy        1                                          no policy
# 2     no policy        1  All ferries to/from Italy & other red areas ar...
# 3     no policy        0                                          no policy
# 4     no policy        0                                          no policy
#
#    Citizen_ban Citizen_ban_info  Travel_history_ban Travel_history_ban_info  \
# 0            0        no policy                   0               no policy
# 1            0        no policy                   0               no policy
# 2            0        no policy                   0               no policy
# 3            0        no policy                   0               no policy
# 4            0        no policy                   0               no policy
#
#    Refugee_ban Refugee_ban_info  Visa_ban  \
# 0            0        no policy         0
# 1            0        no policy         0
# 2            0        no policy         0
# 3            0        no policy         1
# 4            0        no policy         0
#
#                                       Visa_ban_info  \
# 0                                         no policy
# 1                                         no policy
# 2                                         no policy
# 3  New visa seekers and existing valid visa holders
# 4                                         no policy
#
#                                      Quarantine_type
# 0  No declared requirements.<br>\n\nThere are cur...
# 1  Quarantine requirement at government designate...
# 2  Self Isolation- subject to origin.<br>\n\nTher...
# 3  Self-isolation at own accommodation.\n\nString...
# 4  Self-isolation at own accommodation.\n\nAll tr...

# %%
# doing first merge w/ each of the 3 closure dfs, w/ the travel restrictions df
no_closures_merged = no_closures_df.merge(travel_df, how='inner', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
no_closures_merged.head()
# Out:
#       Country Country_id          Policy_type Policy_subtype  \
# 0     Andorra        AND  NOPOLICYIMPLEMENTED           NONE
# 1  Antarctica        ATA  NOPOLICYIMPLEMENTED           NONE
# 2    Guernsey        GGY  NOPOLICYIMPLEMENTED           NONE
# 3        Guam        GUM  NOPOLICYIMPLEMENTED           NONE
# 4      Jersey        JEY  NOPOLICYIMPLEMENTED           NONE
#
#                                      Quarantine_type
# 0  Home isolation is required until COVID test re...
# 1                                            Unknown
# 2                                            Unknown
# 3  Quarantine Requirement- Unknown where\nPasseng...
# 4                                            Unknown

# %%
# doing second merge w/ each of the 3 closure dfs, with vaccination data
full_closures_all = full_closures_df.merge(vaccinations_df, how='left', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
full_closures_all.sample(5)
# Out:
#                                     Country Country_id Policy_type  \
# 99                                  Uruguay        URY    COMPLETE
# 55                              Saint Lucia        LCA    COMPLETE
# 79   Korea, Democratic People's Republic of        PRK    COMPLETE
# 52                               Kazakhstan        KAZ    COMPLETE
# 100           Holy See (Vatican City State)        VAT    COMPLETE
#
#        Policy_subtype Start_date  Citizen_exceptions  \
# 99      CITIZEN_EXCEP 2020-03-24                   1
# 55   SPECIFIC_COUNTRY 2020-07-03                   1
# 79     ESSENTIAL_ONLY 2020-08-02                   0
# 52      CITIZEN_EXCEP 2020-03-16                   1
# 100        WORK_EXCEP 2020-03-10                   1
#
#                                Citizen_exceptions_info  Country_exceptions  \
# 99                      Nationals, permanent residents                   0
# 55   citizens, permanent residents, family members ...                   1
# 79                                           no policy                   0
# 52   citizens, foreigners with residence permits, f...                   0
# 100                                           Citizens                   0
#
#                                Country_exceptions_info  Work_exceptions_info  \
# 99                                           no policy                     0
# 55   Antigua, Barbuda, Aruba, Anguilla, Bahamas, Ba...                     0
# 79                                           no policy                     0
# 52                                           no policy                     0
# 100                                          no policy                     1
#
#     date  total_vaccinations  avg_daily_vaccinations
# 99   NaN                 NaN                     NaN
# 55   NaN                 NaN                     NaN
# 79   NaN                 NaN                     NaN
# 52   NaN                 NaN                     NaN
# 100  NaN                 NaN                     NaN

# %%
# doing second merge w/ each of the 3 closure dfs, with vaccination data
partial_closures_all = partial_closures_df.merge(vaccinations_df, how='left', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
partial_closures_all.sample(5)
# Out:
#                         Country Country_id Policy_type   Policy_subtype  \
# 68   Saint Martin (French part)        MAF     PARTIAL  CITIZENSHIP_BAN
# 75     Northern Mariana Islands        MNP     PARTIAL   BORDER_CLOSURE
# 63                      Liberia        LBR     PARTIAL   BORDER_CLOSURE
# 107                      Sweden        SWE     PARTIAL  CITIZENSHIP_BAN
# 19                        China        CHN     PARTIAL         VISA_BAN
#
#     Start_date  Air_ban Air_ban_info  Land_ban Land_ban_info  Sea_ban  \
# 68  2020-08-01        0    no policy         0     no policy        0
# 75  2020-04-06        1    no policy         0     no policy        0
# 63  2020-04-29        0    no policy         1     no policy        0
# 107 2020-12-22        0    no policy         0     no policy        0
# 19  2020-09-23        0    no policy         0     no policy        0
#
#     Sea_ban_info  Citizen_ban  \
# 68     no policy            1
# 75     no policy            0
# 63     no policy            0
# 107    no policy            1
# 19     no policy            0
#
#                                       Citizen_ban_info  Travel_history_ban  \
# 68                            United States of America                   0
# 75                                           no policy                   0
# 63                                           no policy                   0
# 107  Afghanistan, Aland Islands, Albania, Algeria, ...                   0
# 19                                           no policy                   0
#
#     Travel_history_ban_info  Refugee_ban Refugee_ban_info  Visa_ban  \
# 68                no policy            0        no policy         0
# 75                no policy            0        no policy         0
# 63                no policy            0        no policy         0
# 107               no policy            0        no policy         0
# 19                no policy            0        no policy         1
#
#     Visa_ban_info        date  total_vaccinations  avg_daily_vaccinations
# 68      no policy         NaN                 NaN                     NaN
# 75      no policy         NaN                 NaN                     NaN
# 63      no policy         NaN                 NaN                     NaN
# 107     no policy  2021-01-25            192700.0             6097.966667
# 19      no policy  2021-01-20          15000000.0           322152.513514

# %%
# doing second merge w/ each of the 3 closure dfs, with vaccination data
no_closures_all = no_closures_df.merge(vaccinations_df, how='left', on='Country_id', suffixes=('', '_DROP')).drop(columns='Country_DROP')
no_closures_all.head(10)
# Out:
#        Country Country_id          Policy_type Policy_subtype date  \
# 0      Andorra        AND  NOPOLICYIMPLEMENTED           NONE  NaN
# 1   Antarctica        ATA  NOPOLICYIMPLEMENTED           NONE  NaN
# 2     Guernsey        GGY  NOPOLICYIMPLEMENTED           NONE  NaN
# 3         Guam        GUM  NOPOLICYIMPLEMENTED           NONE  NaN
# 4       Jersey        JEY  NOPOLICYIMPLEMENTED           NONE  NaN
# 5    Nicaragua        NIC  NOPOLICYIMPLEMENTED           NONE  NaN
# 6  Puerto Rico        PRI  NOPOLICYIMPLEMENTED           NONE  NaN
# 7   San Marino        SMR  NOPOLICYIMPLEMENTED           NONE  NaN
#
#    total_vaccinations  avg_daily_vaccinations
# 0                 NaN                     NaN
# 1                 NaN                     NaN
# 2                 NaN                     NaN
# 3                 NaN                     NaN
# 4                 NaN                     NaN
# 5                 NaN                     NaN
# 6                 NaN                     NaN
# 7                 NaN                     NaN

# %%
# checking which cols have null values
# replacing nulls (only in vaccination sourced data cols) with 'no information'
# re-checking null values - none left
print(full_closures_all.isnull().sum(), partial_closures_all.isnull().sum(), no_closures_all.isnull().sum())
full_closures_all.fillna('no information', inplace=True)
partial_closures_all.fillna('no information', inplace=True)
no_closures_all.fillna('no information', inplace=True)
full_closures_all.isnull().sum(), partial_closures_all.isnull().sum(), no_closures_all.isnull().sum()
# Out:
# Country                     0
# Country_id                  0
# Policy_type                 0
# Policy_subtype              0
# Start_date                  0
# Citizen_exceptions          0
# Citizen_exceptions_info     0
# Country_exceptions          0
# Country_exceptions_info     0
# Work_exceptions_info        0
# date                       84
# total_vaccinations         84
# avg_daily_vaccinations     84
# dtype: int64 Country                     0
# Country_id                  0
# Policy_type                 0
# Policy_subtype              0
# Start_date                  0
# Air_ban                     0
# Air_ban_info                0
# Land_ban                    0
# Land_ban_info               0
# Sea_ban                     0
# Sea_ban_info                0
# Citizen_ban                 0
# Citizen_ban_info            0
# Travel_history_ban          0
# Travel_history_ban_info     0
# Refugee_ban                 0
# Refugee_ban_info            0
# Visa_ban                    0
# Visa_ban_info               0
# date                       95
# total_vaccinations         95
# avg_daily_vaccinations     95
# dtype: int64 Country                   0
# Country_id                0
# Policy_type               0
# Policy_subtype            0
# date                      8
# total_vaccinations        8
# avg_daily_vaccinations    8
# dtype: int64
# (Country                    0
#  Country_id                 0
#  Policy_type                0
#  Policy_subtype             0
#  Start_date                 0
#  Citizen_exceptions         0
#  Citizen_exceptions_info    0
#  Country_exceptions         0
#  Country_exceptions_info    0
#  Work_exceptions_info       0
#  date                       0
#  total_vaccinations         0
#  avg_daily_vaccinations     0
#  dtype: int64,
#  Country                    0
#  Country_id                 0
#  Policy_type                0
#  Policy_subtype             0
#  Start_date                 0
#  Air_ban                    0
#  Air_ban_info               0
#  Land_ban                   0
#  Land_ban_info              0
#  Sea_ban                    0
#  Sea_ban_info               0
#  Citizen_ban                0
#  Citizen_ban_info           0
#  Travel_history_ban         0
#  Travel_history_ban_info    0
#  Refugee_ban                0
#  Refugee_ban_info           0
#  Visa_ban                   0
#  Visa_ban_info              0
#  date                       0
#  total_vaccinations         0
#  avg_daily_vaccinations     0
#  dtype: int64,
#  Country                   0
#  Country_id                0
#  Policy_type               0
#  Policy_subtype            0
#  date                      0
#  total_vaccinations        0
#  avg_daily_vaccinations    0
#  dtype: int64)

# %%
# replacing the now 'no information' dates with placeholder date '01-01-01' in case datetimes need to be applied
# creating lists to hold the dates
# replacing the date cols with those lists
full_closures_dates = ['01-01-01' if x == 'no information' else x for x in full_closures_all['date']]
partial_closures_dates = ['01-01-01' if x == 'no information' else x for x in partial_closures_all['date']]
no_closures_dates = ['01-01-01' if x == 'no information' else x for x in no_closures_all['date']]

full_closures_all['date'] = full_closures_dates
partial_closures_all['date'] = partial_closures_dates
no_closures_all['date'] = no_closures_dates

# %%
# exporting all policies df to csv
last_date_df.to_csv('Clean/policy_cleaned.csv', index=False)

# %%
# exporting policy level specific dfs to csvs
full_closures_df.to_csv('Clean/full_closures_df', index=False)
partial_closures_df.to_csv('Clean/partial_closures_df', index=False)
no_closures_df.to_csv('Clean/no_closures_df', index=False)
