# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# Loading raw data
path = "Raw/travel_restrictions.csv"
travel_restrictions_raw= pd.read_csv(path) 

travel_restrictions_raw
# Out:
#                adm0_name      iso3           X          Y   published  \
# 0               Kiribati       KIR -157.364320   1.857760  28.06.2020
# 1                 Kosovo       RKS   20.966191  42.467542  21.01.2021
# 2          Kuril Islands  RUS, JPN  147.877949  45.076156         NaN
# 3                 Kuwait       KWT   47.492598  29.539720  05.02.2021
# 4             Kyrgyzstan       KGZ   74.523246  41.462046  01.02.2021
# ..                   ...       ...         ...        ...         ...
# 284               Jordan       JOR   37.129891  30.653807  11.02.2021
# 285  Juan de Nova Island       xFR   42.725159 -17.055056         NaN
# 286           Kazakhstan       KAZ   66.653592  48.019634  01.02.2021
# 287                Kenya       KEN   37.861019   0.534720  03.02.2021
# 288         Kingman Reef       UMI -162.561400   6.478546         NaN
#
#                                                sources  \
# 0    <a href="https://www.gov.uk/foreign-travel-adv...
# 1    <a href="https://www.gov.uk/foreign-travel-adv...
# 2                                                  NaN
# 3    <a href="https://www.gov.uk/foreign-travel-adv...
# 4    <a href="https://www.covidchecker.com/en/">SIT...
# ..                                                 ...
# 284  <a href="https://www.osac.gov/Content/Report/c...
# 285                                                NaN
# 286  <a href="https://www.gov.uk/foreign-travel-adv...
# 287  UNHAS\n  <a href="https://www.osac.gov/Content...
# 288                                                NaN
#
#                                                   info   optional1  \
# 0    Latest News: Tarawa (TRW) is closed. Extremely...  20200628.0
# 1    Latest News: Authorities order weekend lockdow...  20210121.0
# 2                                                  NaN         NaN
# 3    Latest News: Government bans entry for non-cit...  20210205.0
# 4    Latest News: Government reopens borders for fo...  20210201.0
# ..                                                 ...         ...
# 284  International Restrictions:\n**From 20JAN21 pa...  20210211.0
# 285                                                NaN         NaN
# 286  Latest News: Kazakhstan government allows resu...  20210201.0
# 287  Latest News: Digitally-verified negative COVID...  20210203.0
# 288                                                NaN         NaN
#
#                                              optional2  \
# 0    Quarantine requirement outside territory.\nKir...
# 1    Self-isolation at own accommodation- subject t...
# 2                                                  NaN
# 3    Self-isolation at own accommodation.\n\nOn ent...
# 4    Quarantine requirement at government designate...
# ..                                                 ...
# 284  No qurantine requirement.\n\nPassengers arrivi...
# 285                                                NaN
# 286  Self-isolation at own accommodation- subject t...
# 287  Quarantine requirement at government designate...
# 288                                                NaN
#
#                                              optional3  ObjectId
# 0    COVID-19 negative certification required for e...         1
# 1    COVID-19 negative certification required for e...         2
# 2                                                  NaN         3
# 3    COVID-19 negative certification required for e...         4
# 4    COVID-19 negative certification required for e...         5
# ..                                                 ...       ...
# 284  COVID-19 negative certification required for e...       285
# 285                                                NaN       286
# 286  COVID-19 negative certification required for e...       287
# 287  COVID-19 negative certification required for e...       288
# 288                                                NaN       289
#
# [289 rows x 11 columns]

# %%
#Rename columns 
travel_restrictions_raw.rename(columns = {'adm0_name':'Country', 'iso3':'Country_id', 
                              'optional2':'Quarantine_type', 'published': 'Quarantine_start_date'}, inplace = True)

#Only keeping relevant columns 
columns_to_keep = ["Country", "Country_id", "Quarantine_type", "Quarantine_start_date"]

Renamed_df = travel_restrictions_raw[columns_to_keep]
Renamed_df
# Out:
#                  Country Country_id  \
# 0               Kiribati        KIR
# 1                 Kosovo        RKS
# 2          Kuril Islands   RUS, JPN
# 3                 Kuwait        KWT
# 4             Kyrgyzstan        KGZ
# ..                   ...        ...
# 284               Jordan        JOR
# 285  Juan de Nova Island        xFR
# 286           Kazakhstan        KAZ
# 287                Kenya        KEN
# 288         Kingman Reef        UMI
#
#                                        Quarantine_type Quarantine_start_date
# 0    Quarantine requirement outside territory.\nKir...            28.06.2020
# 1    Self-isolation at own accommodation- subject t...            21.01.2021
# 2                                                  NaN                   NaN
# 3    Self-isolation at own accommodation.\n\nOn ent...            05.02.2021
# 4    Quarantine requirement at government designate...            01.02.2021
# ..                                                 ...                   ...
# 284  No qurantine requirement.\n\nPassengers arrivi...            11.02.2021
# 285                                                NaN                   NaN
# 286  Self-isolation at own accommodation- subject t...            01.02.2021
# 287  Quarantine requirement at government designate...            03.02.2021
# 288                                                NaN                   NaN
#
# [289 rows x 4 columns]

# %%
date_list = [x.replace('.') for x in Renamed_df['Quarantine_start_date']]

# %%
# changing start date to datetime object
Renamed_df['Quarantine_start_date'] = pd.to_datetime(Renamed_df['Quarantine_start_date'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: year 20201 is out of range
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     656         except ValueError as e:
# --> 657             six.raise_from(ParserError(e.args[0] + ": %s", timestr), e)
#     658
#
# ~/~Applications/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: year 20201 is out of range: 04.02.20201
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     654         try:
# --> 655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
#
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in _build_naive(self, res, default)
#    1240
# -> 1241         naive = default.replace(**repl)
#    1242
#
# ValueError: year 20201 is out of range
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-2d81d9a9dee7> in <module>
#       1 # changing start date to datetime object
# ----> 2 Renamed_df['Quarantine_start_date'] = pd.to_datetime(Renamed_df['Quarantine_start_date'])
#
# ~/~Applications/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#     797                 result = result.tz_localize(tz)
#     798     elif isinstance(arg, ABCSeries):
# --> 799         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#     800         if not cache_array.empty:
#     801             result = arg.map(cache_array)
#
# ~/~Applications/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     168         unique_dates = unique(arg)
#     169         if len(unique_dates) < len(arg):
# --> 170             cache_dates = convert_listlike(unique_dates, format)
#     171             cache_array = Series(cache_dates, index=unique_dates)
#     172     return cache_array
#
# ~/~Applications/lib/python3.8/site-packages/pandas/core/tools/datetimes.py in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     457         assert format is None or infer_datetime_format
#     458         utc = tz == "utc"
# --> 459         result, tz_parsed = objects_to_datetime64ns(
#     460             arg,
#     461             dayfirst=dayfirst,
#
# ~/~Applications/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2057             return values.view("i8"), tz_parsed
#    2058         except (ValueError, TypeError):
# -> 2059             raise e
#    2060
#    2061     if tz_parsed is not None:
#
# ~/~Applications/lib/python3.8/site-packages/pandas/core/arrays/datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    2042
#    2043     try:
# -> 2044         result, tz_parsed = tslib.array_to_datetime(
#    2045             data,
#    2046             errors=errors,
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime_object()
#
# pandas/_libs/tslibs/parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(timestr, parserinfo, **kwargs)
#    1372         return parser(parserinfo).parse(timestr, **kwargs)
#    1373     else:
# -> 1374         return DEFAULTPARSER.parse(timestr, **kwargs)
#    1375
#    1376
#
# ~/~Applications/lib/python3.8/site-packages/dateutil/parser/_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     655             ret = self._build_naive(res, default)
#     656         except ValueError as e:
# --> 657             six.raise_from(ParserError(e.args[0] + ": %s", timestr), e)
#     658
#     659         if not ignoretz:
#
# ~/~Applications/lib/python3.8/site-packages/six.py in raise_from(value, from_value)
#
# ParserError: year 20201 is out of range: 04.02.20201

# %%
#Rename NaNs in Quarantine type to "unknown"
non_nans_df= Renamed_df.fillna("Unknown")
non_nans_df

# %%
#Drop any Country ID's with more than one country ID or starts with x (They are territories)
df = non_nans_df[~non_nans_df["Country_id"].str.contains(",")&~non_nans_df["Country_id"].str.contains("x")]

df

# %%
df.reset_index(drop= True, inplace =True)
df

# %%
#Save to output file 
df.to_csv('Clean/travel_restrictions_clean.csv', index=False)
